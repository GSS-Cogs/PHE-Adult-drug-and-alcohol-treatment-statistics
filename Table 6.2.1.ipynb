395109>, <F9 0.35830780693766>, <D33 0.334867663981588>, <C22 26.8349550211125>, <I13 9.57313144329896>, <C31 10.15>, <C13 16.8282860824742>, <B8 9574.0>, <F16 0.299292214357937>, <F13 0.339884020618557>, <E23 0.0416666666666667>, <C19 10.5078725741487>, <I21 11.7947862356621>, <B13 3104.0>, <B16 6923.0>, <I23 4.21759259259259>, <D23 0.662037037037037>, <H16 0.0313447927199191>, <B22 5447.0>, <B35 48.0>, <F33 0.437738477378717>, <F14 0.473921289710763>, <E13 0.0821520618556701>, <I27 4.76335877862596>, <E20 0.0824915824915825>, <D28 0.478445529836483>, <D10 0.378376031263569>, <C7 22.1390569436107>, <D11 0.714905933429812>, <D18 0.568877551020408>, <I16 7.53040589339882>, <F12 0.386206896551724>, <D19 0.654705236177224>, <D8 0.484437016920827>, <F20 0.323232323232323>, <F29 0.46829727187206>, <D29 0.323047977422389>, <B11 691.0>, <E14 0.130867709815078>, <I15 21.6165716378092>, <I19 2.42182350787257>, <H23 0.0324074074074074>, <D15 0.211225610712978>, <C28 19.9624124017837>, <E8 0.23417589304366>, <C33 21.4168433165769>, <B31 100.0>, <D31 0.77>, <F19 0.208348590259978>, <D21 0.370177267987487>, <E19 0.118271695349689>, <D27 0.636132315521629>, <I10 8.12488059053408>, <B23 216.0>, <E16 0.129134768164091>, <F28 0.375026544913994>, <C21 22.3413972888425>}

# %%
reason = tab.excel_ref('A6').expand(DOWN).is_not_blank() 
reason
# Out:
# {<A32 'Alcohol only'>, <A19 'Cocaine use'>, <A21 'Cannabis use'>, <A34 'Tobacco use'>, <A9 '          Opiate use (in opiate and crack clients)'>, <A7 'Opiate use (all opiate clients)'>, <A24 'Non-opiate and Alcohol'>, <A35 'Injecting'>, <A10 'Crack use'>, <A13 'Cannabis use'>, <A12 'Amphetamines use'>, <A30 'Tobacco use'>, <A25 'Crack use'>, <A6 'Opiates'>, <A14 'Alcohol use'>, <A20 'Amphetamines use'>, <A11 'Cocaine use'>, <A26 'Cocaine use'>, <A8 '          Opiate use (in opiate only clients)'>, <A29 'Alcohol use'>, <A23 'Injecting'>, <A17 'Non-opiate only'>, <A18 'Crack use'>, <A28 'Cannabis use'>, <A22 'Tobacco use'>, <A16 'Injecting'>, <A33 'Alcohol use'>, <A27 'Amphetamines use'>, <A31 'Injecting'>, <A15 'Tobacco use'>}

# %%
clients = tab.excel_ref('B4').expand(RIGHT).is_not_blank()
clients
# Out:
# {<F4 'Unchanged'>, <D4 'Abstinent'>, <C4 'Average days of use at start'>, <H4 'Deteriorated'>, <B4 'Reviewed clients using at start'>, <E4 'Improved'>, <I4 'Average days of use at review'>}

# %%
Treatmentstatus = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
Treatmentstatus
# Out:
# {<D3 'AT SIX MONTH REVIEW'>, <B3 'START OF TREATMENT'>}

# %%
MeasureType = tab.excel_ref('B5').expand(RIGHT).is_not_blank()
MeasureType
# Out:
# {<B5 'n'>, <H5 '%'>, <C5 'mean'>, <E5 '%'>, <D5 '%'>, <F5 '%'>, <I5 'mean'>}

# %%
Dimensions = [
            HDim(clients,'Clients in treatment',CLOSEST,LEFT),
            HDim(Treatmentstatus,'Treatment Status',CLOSEST,LEFT),
            HDim(reason,'Substance',DIRECTLY,LEFT),
            HDim(MeasureType,'Measure Type',DIRECTLY,ABOVE),
            HDimConst('Unit','People')            
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# if is_interactive():
#     savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#               OBS             Clients in treatment     Treatment Status  \
# 0    21653.000000  Reviewed clients using at start   START OF TREATMENT
# 1       22.139057     Average days of use at start   START OF TREATMENT
# 2        0.399067                        Abstinent  AT SIX MONTH REVIEW
# 3        0.249296                         Improved  AT SIX MONTH REVIEW
# 4        0.312705                        Unchanged  AT SIX MONTH REVIEW
# 5        0.038932                     Deteriorated  AT SIX MONTH REVIEW
# 6        8.552071    Average days of use at review  AT SIX MONTH REVIEW
# 7     9574.000000  Reviewed clients using at start   START OF TREATMENT
# 8       22.941926     Average days of use at start   START OF TREATMENT
# 9        0.484437                        Abstinent  AT SIX MONTH REVIEW
# 10       0.234176                         Improved  AT SIX MONTH REVIEW
# 11       0.255170                        Unchanged  AT SIX MONTH REVIEW
# 12       0.026217                     Deteriorated  AT SIX MONTH REVIEW
# 13       6.989659    Average days of use at review  AT SIX MONTH REVIEW
# 14   12079.000000  Reviewed clients using at start   START OF TREATMENT
# 15      21.502691     Average days of use at start   START OF TREATMENT
# 16       0.331402                        Abstinent  AT SIX MONTH REVIEW
# 17       0.261280                         Improved  AT SIX MONTH REVIEW
# 18       0.358308                        Unchanged  AT SIX MONTH REVIEW
# 19       0.049011                     Deteriorated  AT SIX MONTH REVIEW
# 20       9.790463    Average days of use at review  AT SIX MONTH REVIEW
# 21   11515.000000  Reviewed clients using at start   START OF TREATMENT
# 22      15.683543     Average days of use at start   START OF TREATMENT
# 23       0.378376                        Abstinent  AT SIX MONTH REVIEW
# 24       0.184195                         Improved  AT SIX MONTH REVIEW
# 25       0.370386                        Unchanged  AT SIX MONTH REVIEW
# 26       0.067043                     Deteriorated  AT SIX MONTH REVIEW
# 27       8.124881    Average days of use at review  AT SIX MONTH REVIEW
# 28     691.000000  Reviewed clients using at start   START OF TREATMENT
# 29       8.001447     Average days of use at start   START OF TREATMENT
# ..            ...                              ...                  ...
# 140      9.758608    Average days of use at review  AT SIX MONTH REVIEW
# 141   6896.000000  Reviewed clients using at start   START OF TREATMENT
# 142     26.664298     Average days of use at start   START OF TREATMENT
# 143      0.315110                        Abstinent  AT SIX MONTH REVIEW
# 144     18.419954    Average days of use at review  AT SIX MONTH REVIEW
# 145    100.000000  Reviewed clients using at start   START OF TREATMENT
# 146     10.150000     Average days of use at start   START OF TREATMENT
# 147      0.770000                        Abstinent  AT SIX MONTH REVIEW
# 148      0.010000                         Improved  AT SIX MONTH REVIEW
# 149      0.210000                        Unchanged  AT SIX MONTH REVIEW
# 150      0.010000                     Deteriorated  AT SIX MONTH REVIEW
# 151      2.900000    Average days of use at review  AT SIX MONTH REVIEW
# 152  33022.000000  Reviewed clients using at start   START OF TREATMENT
# 153     21.416843     Average days of use at start   START OF TREATMENT
# 154      0.334868                        Abstinent  AT SIX MONTH REVIEW
# 155      0.202532                         Improved  AT SIX MONTH REVIEW
# 156      0.437738                        Unchanged  AT SIX MONTH REVIEW
# 157      0.024862                     Deteriorated  AT SIX MONTH REVIEW
# 158     11.060202    Average days of use at review  AT SIX MONTH REVIEW
# 159  14613.000000  Reviewed clients using at start   START OF TREATMENT
# 160     26.820023     Average days of use at start   START OF TREATMENT
# 161      0.336892                        Abstinent  AT SIX MONTH REVIEW
# 162     17.938069    Average days of use at review  AT SIX MONTH REVIEW
# 163     48.000000  Reviewed clients using at start   START OF TREATMENT
# 164     14.166667     Average days of use at start   START OF TREATMENT
# 165      0.916667                        Abstinent  AT SIX MONTH REVIEW
# 166      0.000000                         Improved  AT SIX MONTH REVIEW
# 167      0.083333                        Unchanged  AT SIX MONTH REVIEW
# 168      0.000000                     Deteriorated  AT SIX MONTH REVIEW
# 169      1.000000    Average days of use at review  AT SIX MONTH REVIEW
#
#                                              Substance Measure Type    Unit
# 0                      Opiate use (all opiate clients)            n  People
# 1                      Opiate use (all opiate clients)         mean  People
# 2                      Opiate use (all opiate clients)            %  People
# 3                      Opiate use (all opiate clients)            %  People
# 4                      Opiate use (all opiate clients)            %  People
# 5                      Opiate use (all opiate clients)            %  People
# 6                      Opiate use (all opiate clients)         mean  People
# 7                  Opiate use (in opiate only clients)            n  People
# 8                  Opiate use (in opiate only clients)         mean  People
# 9                  Opiate use (in opiate only clients)            %  People
# 10                 Opiate use (in opiate only clients)            %  People
# 11                 Opiate use (in opiate only clients)            %  People
# 12                 Opiate use (in opiate only clients)            %  People
# 13                 Opiate use (in opiate only clients)         mean  People
# 14             Opiate use (in opiate and crack clie...            n  People
# 15             Opiate use (in opiate and crack clie...         mean  People
# 16             Opiate use (in opiate and crack clie...            %  People
# 17             Opiate use (in opiate and crack clie...            %  People
# 18             Opiate use (in opiate and crack clie...            %  People
# 19             Opiate use (in opiate and crack clie...            %  People
# 20             Opiate use (in opiate and crack clie...         mean  People
# 21                                           Crack use            n  People
# 22                                           Crack use         mean  People
# 23                                           Crack use            %  People
# 24                                           Crack use            %  People
# 25                                           Crack use            %  People
# 26                                           Crack use            %  People
# 27                                           Crack use         mean  People
# 28                                         Cocaine use            n  People
# 29                                         Cocaine use         mean  People
# ..                                                 ...          ...     ...
# 140                                        Alcohol use         mean  People
# 141                                        Tobacco use            n  People
# 142                                        Tobacco use         mean  People
# 143                                        Tobacco use            %  People
# 144                                        Tobacco use         mean  People
# 145                                          Injecting            n  People
# 146                                          Injecting         mean  People
# 147                                          Injecting            %  People
# 148                                          Injecting            %  People
# 149                                          Injecting            %  People
# 150                                          Injecting            %  People
# 151                                          Injecting         mean  People
# 152                                        Alcohol use            n  People
# 153                                        Alcohol use         mean  People
# 154                                        Alcohol use            %  People
# 155                                        Alcohol use            %  People
# 156                                        Alcohol use            %  People
# 157                                        Alcohol use            %  People
# 158                                        Alcohol use         mean  People
# 159                                        Tobacco use            n  People
# 160                                        Tobacco use         mean  People
# 161                                        Tobacco use            %  People
# 162                                        Tobacco use         mean  People
# 163                                          Injecting            n  People
# 164                                          Injecting         mean  People
# 165                                          Injecting            %  People
# 166                                          Injecting            %  People
# 167                                          Injecting            %  People
# 168                                          Injecting            %  People
# 169                                          Injecting         mean  People
#
# [170 rows x 6 columns]

# %%
new_table = new_table[new_table['OBS'] != 0 ]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table.head()
# Out:
#           Value             Clients in treatment     Treatment Status  \
# 0  21653.000000  Reviewed clients using at start   START OF TREATMENT
# 1     22.139057     Average days of use at start   START OF TREATMENT
# 2      0.399067                        Abstinent  AT SIX MONTH REVIEW
# 3      0.249296                         Improved  AT SIX MONTH REVIEW
# 4      0.312705                        Unchanged  AT SIX MONTH REVIEW
#
#                          Substance Measure Type    Unit
# 0  Opiate use (all opiate clients)            n  People
# 1  Opiate use (all opiate clients)         mean  People
# 2  Opiate use (all opiate clients)            %  People
# 3  Opiate use (all opiate clients)            %  People
# 4  Opiate use (all opiate clients)            %  People

# %%
new_table['Measure Type'].unique()
# Out:
# array(['Count', 'mean', 'Percentage'], dtype=object)

# %%
new_table['Measure Type'] = new_table['Measure Type'].map(
    lambda x: {
        'n' : 'Count', 
        '%' : 'Percentage'
        }.get(x, x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table.tail()
# Out:
#          Value             Clients in treatment     Treatment Status  \
# 163  48.000000  Reviewed clients using at start   START OF TREATMENT
# 164  14.166667     Average days of use at start   START OF TREATMENT
# 165   0.916667                        Abstinent  AT SIX MONTH REVIEW
# 167   0.083333                        Unchanged  AT SIX MONTH REVIEW
# 169   1.000000    Average days of use at review  AT SIX MONTH REVIEW
#
#      Substance Measure Type    Unit
# 163  Injecting        Count  People
# 164  Injecting         mean  People
# 165  Injecting   Percentage  People
# 167  Injecting   Percentage  People
# 169  Injecting         mean  People

# %%
new_table.dtypes
# Out:
# Value                   float64
# Clients in treatment     object
# Treatment Status         object
# Substance                object
# Measure Type             object
# Unit                     object
# dtype: object

# %%
new_table['Value'] = new_table['Value'].astype(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table.head(3)
# Out:
#                Value             Clients in treatment     Treatment Status  \
# 0            21653.0  Reviewed clients using at start   START OF TREATMENT
# 1   22.1390569436107     Average days of use at start   START OF TREATMENT
# 2  0.399067103865515                        Abstinent  AT SIX MONTH REVIEW
#
#                          Substance Measure Type    Unit
# 0  Opiate use (all opiate clients)        Count  People
# 1  Opiate use (all opiate clients)         mean  People
# 2  Opiate use (all opiate clients)   Percentage  People

# %%
new_table['Treatment Status'] = new_table['Treatment Status'].map(
    lambda x: {
        'START OF TREATMENT' : 'Start of treatment',
        'AT SIX MONTH REVIEW' : 'At six month Review'
        }.get(x, x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table.tail()
# Out:
#                   Value             Clients in treatment     Treatment Status  \
# 163                48.0  Reviewed clients using at start   Start of treatment
# 164    14.1666666666667     Average days of use at start   Start of treatment
# 165   0.916666666666667                        Abstinent  At six month Review
# 167  0.0833333333333333                        Unchanged  At six month Review
# 169                 1.0    Average days of use at review  At six month Review
#
#      Substance Measure Type    Unit
# 163  Injecting        Count  People
# 164  Injecting         mean  People
# 165  Injecting   Percentage  People
# 167  Injecting   Percentage  People
# 169  Injecting         mean  People

# %%
new_table = new_table[['Substance','Treatment Status','Clients in treatment','Measure Type','Value','Unit']]

# %%
if is_interactive():
    SubstancetinationFolder = Path('out')
    SubstancetinationFolder.mkdir(exist_ok=True, parents=True)
    new_table.to_csv(SubstancetinationFolder / ('table6.2.1.csv'), index = False)
