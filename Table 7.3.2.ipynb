# %% [markdown]
# Table 7.3.2: Trends in the proportion of new presentations with housing problems, by NPS and all clients

# %%
from gssutils import *

if is_interactive():
    import requests
    from cachecontrol import CacheControl
    from cachecontrol.caches.file_cache import FileCache
    from cachecontrol.heuristics import LastModified
    from pathlib import Path

    session = CacheControl(requests.Session(),
                           cache=FileCache('.cache'),
                           heuristic=LastModified())

    sourceFolder = Path('in')
    sourceFolder.mkdir(exist_ok=True)

    inputURL = 'https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/752515/AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx'
    inputFile = sourceFolder / 'AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx'
    response = session.get(inputURL)
    with open(inputFile, 'wb') as f:
      f.write(response.content)

# %%
tab = loadxlstabs(inputFile, sheetids='Table 7.3.2')[0]
# Out:
# Loading in\AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx which has size 272149 bytes
# Table names: ['Table 7.3.2']

# %% [markdown]
# https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/752515/AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx

# %%
observations = tab.excel_ref('B6').expand(DOWN).expand(RIGHT).is_not_blank()
observations
# Out:
# {<F11 10.0>, <Q9 0.015330380128487604>, <J10 2016.0>, <J12 4058.0>, <I8 0.806111857148042>, <I10 1.0>, <R11 12.0>, <S10 1.0>, <E6 0.06582228685029469>, <D10 142353.0>, <L7 15569.0>, <P6 9442.0>, <T11 1287.0>, <M8 0.8047303675733082>, <E10 1.0>, <O10 1.0>, <H7 16009.0>, <D11 5105.0>, <D6 9370.0>, <T9 1941.0>, <F6 115.0>, <D12 289811.0>, <U7 0.1113870814156483>, <S8 0.5194054500412882>, <O7 0.17593244194229415>, <Q6 0.07299518364759452>, <P10 129351.0>, <L9 1848.0>, <N6 262.0>, <L10 135592.0>, <T8 100275.0>, <T6 9767.0>, <B7 40.0>, <B10 318.0>, <I6 0.06572786992342032>, <F12 2298.0>, <N10 1421.0>, <O8 0.5932441942294159>, <G6 0.10052447552447552>, <K9 0.06001984126984127>, <T12 253327.0>, <L12 273673.0>, <J8 1253.0>, <D9 1732.0>, <M7 0.11482240840167561>, <J6 286.0>, <M6 0.06681810136291226>, <B8 225.0>, <S6 0.24690338563170933>, <H11 3881.0>, <C7 0.12578616352201258>, <B12 638.0>, <H6 9055.0>, <U6 0.07750357086176797>, <U9 0.015402317092524997>, <J9 121.0>, <L11 2489.0>, <K10 1.0>, <S9 0.023947151114781174>, <L6 9060.0>, <U10 1.0>, <Q8 0.7994758447943966>, <L8 109115.0>, <E9 0.012166937121100363>, <G10 1.0>, <E7 0.11704705907146319>, <C8 0.7075471698113207>, <R6 299.0>, <H12 279411.0>, <G9 0.07867132867132867>, <C6 0.06289308176100629>, <N12 2871.0>, <R9 29.0>, <H10 137765.0>, <R7 254.0>, <U8 0.7957070306300588>, <M9 0.013629122662103959>, <O6 0.18437719915552428>, <P8 103413.0>, <Q10 1.0>, <F9 90.0>, <C10 1.0>, <F7 166.0>, <G7 0.1451048951048951>, <K6 0.14186507936507936>, <H9 1647.0>, <D8 114589.0>, <T10 126020.0>, <M10 1.0>, <R8 629.0>, <R12 2434.0>, <N8 843.0>, <K8 0.6215277777777778>, <I9 0.01195514100097993>, <P9 1983.0>, <B11 2.0>, <P12 260567.0>, <F10 1144.0>, <H8 111054.0>, <J7 356.0>, <Q7 0.11219859142952122>, <K7 0.1765873015873016>, <G8 0.6756993006993007>, <D7 16662.0>, <P7 14513.0>, <O9 0.04644616467276566>, <R10 1211.0>, <P11 1865.0>, <C9 0.10377358490566038>, <J11 26.0>, <N11 29.0>, <N7 250.0>, <I7 0.1162051319275578>, <E8 0.8049637169571418>, <B6 20.0>, <S7 0.2097440132122213>, <B9 33.0>, <T7 14037.0>, <F8 773.0>, <N9 66.0>}

# %%
house = tab.excel_ref('A6').expand(DOWN).is_not_blank() - tab.excel_ref('A12').expand(DOWN)
house
# Out:
# {<A7 'Housing problem'>, <A10 'Total'>, <A11 'Not stated/missing'>, <A6 'Urgent problem'>, <A9 'Other'>, <A8 'No problem'>}

# %%
Clients = tab.excel_ref('B4').expand(RIGHT).is_not_blank()
Clients
# Out:
# {<R4 'NPS'>, <H4 'All'>, <L4 'All'>, <D4 'All'>, <B4 'NPS'>, <F4 'NPS'>, <J4 'NPS'>, <P4 'All'>, <N4 'NPS'>, <T4 'All'>}

# %%
period = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
period
# Out:
# {<N3 '2016-17'>, <R3 '2017-18'>, <B3 '2013-14'>, <F3 '2014-15'>, <J3 '2015-16'>}

# %%
MeasureType = tab.excel_ref('B5').expand(RIGHT).is_not_blank()
MeasureType
# Out:
# {<F5 'n'>, <P5 'n'>, <S5 '%'>, <B5 'n'>, <L5 'n'>, <N5 'n'>, <E5 '%'>, <J5 'n'>, <T5 'n'>, <G5 '%'>, <D5 'n'>, <M5 '%'>, <R5 'n'>, <C5 '%'>, <I5 '%'>, <O5 '%'>, <H5 'n'>, <U5 '%'>, <K5 '%'>, <Q5 '%'>}

# %%
Dimensions = [
            HDim(house,'Housing Status',DIRECTLY,LEFT),
            HDim(Clients,'Clients in new treatment',CLOSEST,LEFT),
            HDim(MeasureType,'Measure Type',DIRECTLY,ABOVE),
            HDim(period,'Period',CLOSEST,LEFT),
            HDimConst('Unit','People')            
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# if is_interactive():
#     savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#                OBS      Housing Status Clients in new treatment Measure Type  \
# 0        20.000000      Urgent problem                      NPS            n
# 1         0.062893      Urgent problem                      NPS            %
# 2      9370.000000      Urgent problem                      All            n
# 3         0.065822      Urgent problem                      All            %
# 4       115.000000      Urgent problem                      NPS            n
# 5         0.100524      Urgent problem                      NPS            %
# 6      9055.000000      Urgent problem                      All            n
# 7         0.065728      Urgent problem                      All            %
# 8       286.000000      Urgent problem                      NPS            n
# 9         0.141865      Urgent problem                      NPS            %
# 10     9060.000000      Urgent problem                      All            n
# 11        0.066818      Urgent problem                      All            %
# 12      262.000000      Urgent problem                      NPS            n
# 13        0.184377      Urgent problem                      NPS            %
# 14     9442.000000      Urgent problem                      All            n
# 15        0.072995      Urgent problem                      All            %
# 16      299.000000      Urgent problem                      NPS            n
# 17        0.246903      Urgent problem                      NPS            %
# 18     9767.000000      Urgent problem                      All            n
# 19        0.077504      Urgent problem                      All            %
# 20       40.000000     Housing problem                      NPS            n
# 21        0.125786     Housing problem                      NPS            %
# 22    16662.000000     Housing problem                      All            n
# 23        0.117047     Housing problem                      All            %
# 24      166.000000     Housing problem                      NPS            n
# 25        0.145105     Housing problem                      NPS            %
# 26    16009.000000     Housing problem                      All            n
# 27        0.116205     Housing problem                      All            %
# 28      356.000000     Housing problem                      NPS            n
# 29        0.176587     Housing problem                      NPS            %
# ..             ...                 ...                      ...          ...
# 90   135592.000000               Total                      All            n
# 91        1.000000               Total                      All            %
# 92     1421.000000               Total                      NPS            n
# 93        1.000000               Total                      NPS            %
# 94   129351.000000               Total                      All            n
# 95        1.000000               Total                      All            %
# 96     1211.000000               Total                      NPS            n
# 97        1.000000               Total                      NPS            %
# 98   126020.000000               Total                      All            n
# 99        1.000000               Total                      All            %
# 100       2.000000  Not stated/missing                      NPS            n
# 101    5105.000000  Not stated/missing                      All            n
# 102      10.000000  Not stated/missing                      NPS            n
# 103    3881.000000  Not stated/missing                      All            n
# 104      26.000000  Not stated/missing                      NPS            n
# 105    2489.000000  Not stated/missing                      All            n
# 106      29.000000  Not stated/missing                      NPS            n
# 107    1865.000000  Not stated/missing                      All            n
# 108      12.000000  Not stated/missing                      NPS            n
# 109    1287.000000  Not stated/missing                      All            n
# 110     638.000000                None                      NPS            n
# 111  289811.000000                None                      All            n
# 112    2298.000000                None                      NPS            n
# 113  279411.000000                None                      All            n
# 114    4058.000000                None                      NPS            n
# 115  273673.000000                None                      All            n
# 116    2871.000000                None                      NPS            n
# 117  260567.000000                None                      All            n
# 118    2434.000000                None                      NPS            n
# 119  253327.000000                None                      All            n
#
#       Period    Unit
# 0    2013-14  People
# 1    2013-14  People
# 2    2013-14  People
# 3    2013-14  People
# 4    2014-15  People
# 5    2014-15  People
# 6    2014-15  People
# 7    2014-15  People
# 8    2015-16  People
# 9    2015-16  People
# 10   2015-16  People
# 11   2015-16  People
# 12   2016-17  People
# 13   2016-17  People
# 14   2016-17  People
# 15   2016-17  People
# 16   2017-18  People
# 17   2017-18  People
# 18   2017-18  People
# 19   2017-18  People
# 20   2013-14  People
# 21   2013-14  People
# 22   2013-14  People
# 23   2013-14  People
# 24   2014-15  People
# 25   2014-15  People
# 26   2014-15  People
# 27   2014-15  People
# 28   2015-16  People
# 29   2015-16  People
# ..       ...     ...
# 90   2015-16  People
# 91   2015-16  People
# 92   2016-17  People
# 93   2016-17  People
# 94   2016-17  People
# 95   2016-17  People
# 96   2017-18  People
# 97   2017-18  People
# 98   2017-18  People
# 99   2017-18  People
# 100  2013-14  People
# 101  2013-14  People
# 102  2014-15  People
# 103  2014-15  People
# 104  2015-16  People
# 105  2015-16  People
# 106  2016-17  People
# 107  2016-17  People
# 108  2017-18  People
# 109  2017-18  People
# 110  2013-14  People
# 111  2013-14  People
# 112  2014-15  People
# 113  2014-15  People
# 114  2015-16  People
# 115  2015-16  People
# 116  2016-17  People
# 117  2016-17  People
# 118  2017-18  People
# 119  2017-18  People
#
# [120 rows x 6 columns]

# %%
new_table = new_table[new_table['OBS'] != 0 ]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table.head()
# Out:
#          Value  Housing Status Clients in new treatment Measure Type   Period  \
# 0    20.000000  Urgent problem                      NPS            n  2013-14
# 1     0.062893  Urgent problem                      NPS            %  2013-14
# 2  9370.000000  Urgent problem                      All            n  2013-14
# 3     0.065822  Urgent problem                      All            %  2013-14
# 4   115.000000  Urgent problem                      NPS            n  2014-15
#
#      Unit
# 0  People
# 1  People
# 2  People
# 3  People
# 4  People

# %%
new_table['Measure Type'] = new_table['Measure Type'].map(
    lambda x: {
        'n' : 'Count', 
        '%' : 'Percentage',
        }.get(x, x))

# %%
new_table.tail()
# Out:
#         Value Housing Status Clients in new treatment Measure Type   Period  \
# 115  273673.0           None                      All        Count  2015-16
# 116    2871.0           None                      NPS        Count  2016-17
# 117  260567.0           None                      All        Count  2016-17
# 118    2434.0           None                      NPS        Count  2017-18
# 119  253327.0           None                      All        Count  2017-18
#
#        Unit
# 115  People
# 116  People
# 117  People
# 118  People
# 119  People

# %%
new_table.dtypes
# Out:
# Value                       float64
# Housing Status               object
# Clients in new treatment     object
# Measure Type                 object
# Period                       object
# Unit                         object
# dtype: object

# %%
new_table['Value'] = new_table['Value'].astype(str)

# %%
new_table.head(3)
# Out:
#                  Value  Housing Status Clients in new treatment Measure Type  \
# 0                 20.0  Urgent problem                      NPS        Count
# 1  0.06289308176100629  Urgent problem                      NPS   Percentage
# 2               9370.0  Urgent problem                      All        Count
#
#     Period    Unit
# 0  2013-14  People
# 1  2013-14  People
# 2  2013-14  People

# %%
new_table['Housing Status'] = new_table['Housing Status'].map(
    lambda x: {
        'Total' : 'All' 
        }.get(x, x))

# %%
def user_perc(x):
    
    if x == None:
        return 'All inclusice Not stated/missing'
    else:
        return x
    
new_table['Housing Status'] = new_table.apply(lambda row: user_perc(row['Housing Status']), axis = 1)

# %%
new_table.head(3)
# Out:
#                  Value  Housing Status Clients in new treatment Measure Type  \
# 0                 20.0  Urgent problem                      NPS        Count
# 1  0.06289308176100629  Urgent problem                      NPS   Percentage
# 2               9370.0  Urgent problem                      All        Count
#
#     Period    Unit
# 0  2013-14  People
# 1  2013-14  People
# 2  2013-14  People

# %%
new_table = new_table[['Period','Housing Status','Clients in new treatment','Measure Type','Value','Unit']]

# %%
if is_interactive():
    SubstancetinationFolder = Path('out')
    SubstancetinationFolder.mkdir(exist_ok=True, parents=True)
    new_table.to_csv(SubstancetinationFolder / ('table7.3.2.csv'), index = False)
