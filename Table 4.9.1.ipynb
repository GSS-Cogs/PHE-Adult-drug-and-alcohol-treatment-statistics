# %% [markdown]
# Table 4.9.1: Substance breakdown of new presentations to treatment

# %%
from gssutils import *

if is_interactive():
    import requests
    from cachecontrol import CacheControl
    from cachecontrol.caches.file_cache import FileCache
    from cachecontrol.heuristics import LastModified
    from pathlib import Path

    session = CacheControl(requests.Session(),
                           cache=FileCache('.cache'),
                           heuristic=LastModified())

    sourceFolder = Path('in')
    sourceFolder.mkdir(exist_ok=True)

    inputURL = 'https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/752515/AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx'
    inputFile = sourceFolder / 'AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx'
    response = session.get(inputURL)
    with open(inputFile, 'wb') as f:
      f.write(response.content)

# %%
tab = loadxlstabs(inputFile, sheetids='Table 4.9.1')[0]
# Out:
# Loading in\AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx which has size 272149 bytes
# Table names: ['Table 4.9.1']

# %% [markdown]
# https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/752515/AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx

# %%
observations = tab.excel_ref('B6').expand(DOWN).expand(RIGHT).is_not_blank()
observations
# Out:
# {<J14 1464.0>, <K14 0.0114997604216579>, <B6 18767.0>, <E14 0.0386456089973678>, <K16 0.600100544353413>, <C8 0.0>, <B12 1065.0>, <E8 0.136336444125389>, <G17 1.0>, <B8 0.0>, <D13 910.0>, <H17 50656.0>, <F16 18757.0>, <I13 0.0>, <B7 22411.0>, <I11 0.0>, <J13 4057.0>, <E11 0.382986360373295>, <I7 0.0>, <D10 9566.0>, <G14 0.0170602974889375>, <H7 0.0>, <C6 0.455753072028753>, <H11 0.0>, <G6 0.0>, <H13 0.0>, <G16 1.0>, <G7 0.0>, <F14 320.0>, <D8 2279.0>, <I16 1.0>, <K7 0.176039023777169>, <G11 0.497894119528709>, <C10 0.13805915780271>, <G8 0.107799754758224>, <F17 18757.0>, <F6 0.0>, <H16 50656.0>, <E17 1.0>, <F8 2022.0>, <F13 663.0>, <E6 0.0>, <J6 18767.0>, <C12 0.0258633250764972>, <K13 0.0318678470154823>, <D6 0.0>, <E13 0.0544388609715243>, <C13 0.0603234736995483>, <E10 0.572266092366595>, <J11 17796.0>, <E16 0.0>, <G12 0.0572053100175934>, <D14 646.0>, <C14 0.0120938365146437>, <F11 9339.0>, <C7 0.544246927971247>, <J8 4301.0>, <D16 0.0>, <K11 0.139788071355071>, <K6 0.147415303164791>, <J17 127307.0>, <B14 498.0>, <F10 9918.0>, <B16 6984.0>, <B17 41178.0>, <F12 1073.0>, <D11 6402.0>, <E12 0.0925460636515913>, <I14 0.0>, <J16 76397.0>, <K8 0.0337844737524252>, <I12 0.0>, <I10 0.0>, <I8 0.0>, <C16 0.169605128952353>, <I6 0.0>, <H6 0.0>, <J7 22411.0>, <H8 0.0>, <J10 25169.0>, <I17 1.0>, <H10 0.0>, <K12 0.0289457767444053>, <H12 0.0>, <C11 0.0499052892321142>, <H14 0.0>, <G10 0.528762595297755>, <C17 1.0>, <F7 0.0>, <B13 2484.0>, <D17 16716.0>, <B10 5685.0>, <J12 3685.0>, <G13 0.0353468038598923>, <K10 0.197703189926713>, <K17 1.0>, <D12 1547.0>, <E7 0.0>, <B11 2055.0>, <D7 0.0>}

# %%
Substance = tab.excel_ref('A6').expand(DOWN).is_not_blank() - tab.excel_ref('A19').expand(DOWN)
Substance
# Out:
# {<A7 'Both opiate and crack cocaine'>, <A17 'Total number of individuals*'>, <A13 'Benzodiazepine'>, <A9 'Other drug use'>, <A11 'Cocaine'>, <A14 'Other'>, <A8 'Crack cocaine (not opiate)'>, <A10 'Cannabis'>, <A15 'Alcohol'>, <A16 'Alcohol'>, <A6 'Opiate (not crack cocaine)'>, <A12 'Amphetamine (other than ecstasy)'>}

# %%
Clients = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
Clients
# Out:
# {<J3 'Total'>, <D3 'Non-opiate only'>, <B3 'Opiate'>, <F3 'Non-opiate and Alcohol'>, <H3 'Alcohol only'>}

# %%
MeasureType = tab.excel_ref('B4').expand(RIGHT).is_not_blank()
MeasureType
# Out:
# {<H4 'n'>, <G4 '%'>, <J4 'n'>, <I4 '%'>, <C4 '%'>, <F4 'n'>, <K4 '%'>, <E4 '%'>, <D4 'n'>, <B4 'n'>}

# %%
Dimensions = [
            HDim(Substance,'Substance',DIRECTLY,LEFT),
            HDim(Clients,'Clients in new treatment',CLOSEST,LEFT),
            HDim(MeasureType,'Measure Type',DIRECTLY,ABOVE),
            HDimConst('Unit','People')            
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# if is_interactive():
#     savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#               OBS                      Substance Clients in new treatment  \
# 0    18767.000000     Opiate (not crack cocaine)                   Opiate
# 1        0.455753     Opiate (not crack cocaine)                   Opiate
# 2        0.000000     Opiate (not crack cocaine)          Non-opiate only
# 3        0.000000     Opiate (not crack cocaine)          Non-opiate only
# 4        0.000000     Opiate (not crack cocaine)   Non-opiate and Alcohol
# 5        0.000000     Opiate (not crack cocaine)   Non-opiate and Alcohol
# 6        0.000000     Opiate (not crack cocaine)             Alcohol only
# 7        0.000000     Opiate (not crack cocaine)             Alcohol only
# 8    18767.000000     Opiate (not crack cocaine)                    Total
# 9        0.147415     Opiate (not crack cocaine)                    Total
# 10   22411.000000  Both opiate and crack cocaine                   Opiate
# 11       0.544247  Both opiate and crack cocaine                   Opiate
# 12       0.000000  Both opiate and crack cocaine          Non-opiate only
# 13       0.000000  Both opiate and crack cocaine          Non-opiate only
# 14       0.000000  Both opiate and crack cocaine   Non-opiate and Alcohol
# 15       0.000000  Both opiate and crack cocaine   Non-opiate and Alcohol
# 16       0.000000  Both opiate and crack cocaine             Alcohol only
# 17       0.000000  Both opiate and crack cocaine             Alcohol only
# 18   22411.000000  Both opiate and crack cocaine                    Total
# 19       0.176039  Both opiate and crack cocaine                    Total
# 20       0.000000     Crack cocaine (not opiate)                   Opiate
# 21       0.000000     Crack cocaine (not opiate)                   Opiate
# 22    2279.000000     Crack cocaine (not opiate)          Non-opiate only
# 23       0.136336     Crack cocaine (not opiate)          Non-opiate only
# 24    2022.000000     Crack cocaine (not opiate)   Non-opiate and Alcohol
# 25       0.107800     Crack cocaine (not opiate)   Non-opiate and Alcohol
# 26       0.000000     Crack cocaine (not opiate)             Alcohol only
# 27       0.000000     Crack cocaine (not opiate)             Alcohol only
# 28    4301.000000     Crack cocaine (not opiate)                    Total
# 29       0.033784     Crack cocaine (not opiate)                    Total
# ..            ...                            ...                      ...
# 70     498.000000                          Other                   Opiate
# 71       0.012094                          Other                   Opiate
# 72     646.000000                          Other          Non-opiate only
# 73       0.038646                          Other          Non-opiate only
# 74     320.000000                          Other   Non-opiate and Alcohol
# 75       0.017060                          Other   Non-opiate and Alcohol
# 76       0.000000                          Other             Alcohol only
# 77       0.000000                          Other             Alcohol only
# 78    1464.000000                          Other                    Total
# 79       0.011500                          Other                    Total
# 80    6984.000000                        Alcohol                   Opiate
# 81       0.169605                        Alcohol                   Opiate
# 82       0.000000                        Alcohol          Non-opiate only
# 83       0.000000                        Alcohol          Non-opiate only
# 84   18757.000000                        Alcohol   Non-opiate and Alcohol
# 85       1.000000                        Alcohol   Non-opiate and Alcohol
# 86   50656.000000                        Alcohol             Alcohol only
# 87       1.000000                        Alcohol             Alcohol only
# 88   76397.000000                        Alcohol                    Total
# 89       0.600101                        Alcohol                    Total
# 90   41178.000000   Total number of individuals*                   Opiate
# 91       1.000000   Total number of individuals*                   Opiate
# 92   16716.000000   Total number of individuals*          Non-opiate only
# 93       1.000000   Total number of individuals*          Non-opiate only
# 94   18757.000000   Total number of individuals*   Non-opiate and Alcohol
# 95       1.000000   Total number of individuals*   Non-opiate and Alcohol
# 96   50656.000000   Total number of individuals*             Alcohol only
# 97       1.000000   Total number of individuals*             Alcohol only
# 98  127307.000000   Total number of individuals*                    Total
# 99       1.000000   Total number of individuals*                    Total
#
#    Measure Type    Unit
# 0             n  People
# 1             %  People
# 2             n  People
# 3             %  People
# 4             n  People
# 5             %  People
# 6             n  People
# 7             %  People
# 8             n  People
# 9             %  People
# 10            n  People
# 11            %  People
# 12            n  People
# 13            %  People
# 14            n  People
# 15            %  People
# 16            n  People
# 17            %  People
# 18            n  People
# 19            %  People
# 20            n  People
# 21            %  People
# 22            n  People
# 23            %  People
# 24            n  People
# 25            %  People
# 26            n  People
# 27            %  People
# 28            n  People
# 29            %  People
# ..          ...     ...
# 70            n  People
# 71            %  People
# 72            n  People
# 73            %  People
# 74            n  People
# 75            %  People
# 76            n  People
# 77            %  People
# 78            n  People
# 79            %  People
# 80            n  People
# 81            %  People
# 82            n  People
# 83            %  People
# 84            n  People
# 85            %  People
# 86            n  People
# 87            %  People
# 88            n  People
# 89            %  People
# 90            n  People
# 91            %  People
# 92            n  People
# 93            %  People
# 94            n  People
# 95            %  People
# 96            n  People
# 97            %  People
# 98            n  People
# 99            %  People
#
# [100 rows x 5 columns]

# %%
new_table = new_table[new_table['OBS'] != 0 ]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table.head()
# Out:
#            Value                      Substance Clients in new treatment  \
# 0   18767.000000     Opiate (not crack cocaine)                   Opiate
# 1       0.455753     Opiate (not crack cocaine)                   Opiate
# 8   18767.000000     Opiate (not crack cocaine)                    Total
# 9       0.147415     Opiate (not crack cocaine)                    Total
# 10  22411.000000  Both opiate and crack cocaine                   Opiate
#
#    Measure Type    Unit
# 0             n  People
# 1             %  People
# 8             n  People
# 9             %  People
# 10            n  People

# %%
new_table['Measure Type'] = new_table['Measure Type'].map(
    lambda x: {
        'n' : 'Count', 
        '%' : 'Percentage',
        }.get(x, x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table.tail()
# Out:
#        Value                     Substance Clients in new treatment  \
# 95       1.0  Total number of individuals*   Non-opiate and Alcohol
# 96   50656.0  Total number of individuals*             Alcohol only
# 97       1.0  Total number of individuals*             Alcohol only
# 98  127307.0  Total number of individuals*                    Total
# 99       1.0  Total number of individuals*                    Total
#
#    Measure Type    Unit
# 95   Percentage  People
# 96        Count  People
# 97   Percentage  People
# 98        Count  People
# 99   Percentage  People

# %%
new_table.dtypes
# Out:
# Value                       float64
# Substance                    object
# Clients in new treatment     object
# Measure Type                 object
# Unit                         object
# dtype: object

# %%
new_table['Value'] = new_table['Value'].astype(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table.head(3)
# Out:
#                Value                   Substance Clients in new treatment  \
# 0            18767.0  Opiate (not crack cocaine)                   Opiate
# 1  0.455753072028753  Opiate (not crack cocaine)                   Opiate
# 8            18767.0  Opiate (not crack cocaine)                    Total
#
#   Measure Type    Unit
# 0        Count  People
# 1   Percentage  People
# 8        Count  People

# %%
new_table['Substance'] = new_table['Substance'].str.rstrip('*')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table['Clients in new treatment'] = new_table['Clients in new treatment'].map(
    lambda x: {
        'Total' : 'All Clients' 
        }.get(x, x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table.head(3)
# Out:
#                Value                   Substance Clients in new treatment  \
# 0            18767.0  Opiate (not crack cocaine)                   Opiate
# 1  0.455753072028753  Opiate (not crack cocaine)                   Opiate
# 8            18767.0  Opiate (not crack cocaine)              All Clients
#
#   Measure Type    Unit
# 0        Count  People
# 1   Percentage  People
# 8        Count  People

# %%
new_table = new_table[['Substance','Clients in new treatment','Measure Type','Value','Unit']]

# %%
if is_interactive():
    SubstancetinationFolder = Path('out')
    SubstancetinationFolder.mkdir(exist_ok=True, parents=True)
    new_table.to_csv(SubstancetinationFolder / ('table4.9.1.csv'), index = False)
