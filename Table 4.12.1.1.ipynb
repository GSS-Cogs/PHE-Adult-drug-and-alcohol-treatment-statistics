# %% [markdown]
# Table 4.12.1: Parental status of new presentations to treatment 2017-18

# %%
from gssutils import *

if is_interactive():
    import requests
    from cachecontrol import CacheControl
    from cachecontrol.caches.file_cache import FileCache
    from cachecontrol.heuristics import LastModified
    from pathlib import Path

    session = CacheControl(requests.Session(),
                           cache=FileCache('.cache'),
                           heuristic=LastModified())

    sourceFolder = Path('in')
    sourceFolder.mkdir(exist_ok=True)

    inputURL = 'https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/752515/AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx'
    inputFile = sourceFolder / 'AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx'
    response = session.get(inputURL)
    with open(inputFile, 'wb') as f:
      f.write(response.content)

# %%
tab = loadxlstabs(inputFile, sheetids='Table 4.12.1')[0]
# Out:
# Loading in\AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx which has size 272149 bytes
# Table names: ['Table 4.12.1']

# %% [markdown]
# https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/752515/AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx

# %%
observations = tab.excel_ref('B4').expand(DOWN).expand(RIGHT).is_not_blank() - tab.excel_ref('B11').expand(DOWN).expand(RIGHT)
observations
# Out:
# {<D10 16716.0>, <J10 127307.0>, <E8 1.0>, <F10 18757.0>, <E5 0.0451091545048848>, <K7 0.490698299298223>, <F4 3004.0>, <E7 0.479676757930286>, <D4 3272.0>, <I4 0.199837110903637>, <E6 0.277891689784103>, <J6 38852.0>, <I5 0.0378816471663257>, <H8 50341.0>, <F6 5350.0>, <J4 20255.0>, <H5 1907.0>, <D5 748.0>, <K4 0.160073022697098>, <I8 1.0>, <B4 3919.0>, <G8 1.0>, <H7 25468.0>, <I7 0.505909695874138>, <F9 95.0>, <F8 18662.0>, <F7 9303.0>, <C8 1.0>, <B8 40951.0>, <D6 4608.0>, <B10 41178.0>, <B7 19366.0>, <I6 0.256371546055899>, <D8 16582.0>, <C5 0.0409758003467559>, <B5 1678.0>, <J9 771.0>, <K5 0.0421856230637921>, <K8 1.0>, <C4 0.0956997387121194>, <E4 0.197322397780726>, <C6 0.39041781641474>, <H9 315.0>, <B9 227.0>, <J5 5338.0>, <D9 134.0>, <G5 0.0538527489015111>, <B6 15988.0>, <J7 62091.0>, <G7 0.498499624906227>, <D7 7954.0>, <J8 126536.0>, <F5 1005.0>, <K6 0.307043054940886>, <G4 0.160968813631979>, <H10 50656.0>, <C7 0.472906644526385>, <H4 10060.0>, <G6 0.286678812560283>, <H6 12906.0>}

# %%
PS = tab.excel_ref('A4').expand(DOWN).is_not_blank() - tab.excel_ref('A10').expand(DOWN)
PS
# Out:
# {<A5 'Other contact living with children'>, <A8 'Total'>, <A4 'Parent living with children'>, <A6 'Parents not with children'>, <A7 'Not parent no contact with children'>, <A9 'Incomplete data'>}

# %%
Clients = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
Clients
# Out:
# {<H3 'Alcohol only'>, <B3 'Opiate'>, <D3 'Non-opiate only'>, <F3 'Non-opiate and Alcohol'>, <J3 'Total'>}

# %%
Dimensions = [
            HDim(PS,'Parental status',DIRECTLY,LEFT),
            HDim(Clients,'Clients in new treatment',CLOSEST,LEFT),
            HDimConst('Sex','T'),
            HDimConst('Unit','People')            
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# if is_interactive():
#     savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#               OBS                      Parental status  \
# 0     3919.000000          Parent living with children
# 1        0.095700          Parent living with children
# 2     3272.000000          Parent living with children
# 3        0.197322          Parent living with children
# 4     3004.000000          Parent living with children
# 5        0.160969          Parent living with children
# 6    10060.000000          Parent living with children
# 7        0.199837          Parent living with children
# 8    20255.000000          Parent living with children
# 9        0.160073          Parent living with children
# 10    1678.000000   Other contact living with children
# 11       0.040976   Other contact living with children
# 12     748.000000   Other contact living with children
# 13       0.045109   Other contact living with children
# 14    1005.000000   Other contact living with children
# 15       0.053853   Other contact living with children
# 16    1907.000000   Other contact living with children
# 17       0.037882   Other contact living with children
# 18    5338.000000   Other contact living with children
# 19       0.042186   Other contact living with children
# 20   15988.000000            Parents not with children
# 21       0.390418            Parents not with children
# 22    4608.000000            Parents not with children
# 23       0.277892            Parents not with children
# 24    5350.000000            Parents not with children
# 25       0.286679            Parents not with children
# 26   12906.000000            Parents not with children
# 27       0.256372            Parents not with children
# 28   38852.000000            Parents not with children
# 29       0.307043            Parents not with children
# 30   19366.000000  Not parent no contact with children
# 31       0.472907  Not parent no contact with children
# 32    7954.000000  Not parent no contact with children
# 33       0.479677  Not parent no contact with children
# 34    9303.000000  Not parent no contact with children
# 35       0.498500  Not parent no contact with children
# 36   25468.000000  Not parent no contact with children
# 37       0.505910  Not parent no contact with children
# 38   62091.000000  Not parent no contact with children
# 39       0.490698  Not parent no contact with children
# 40   40951.000000                                Total
# 41       1.000000                                Total
# 42   16582.000000                                Total
# 43       1.000000                                Total
# 44   18662.000000                                Total
# 45       1.000000                                Total
# 46   50341.000000                                Total
# 47       1.000000                                Total
# 48  126536.000000                                Total
# 49       1.000000                                Total
# 50     227.000000                      Incomplete data
# 51     134.000000                      Incomplete data
# 52      95.000000                      Incomplete data
# 53     315.000000                      Incomplete data
# 54     771.000000                      Incomplete data
# 55   41178.000000                                 None
# 56   16716.000000                                 None
# 57   18757.000000                                 None
# 58   50656.000000                                 None
# 59  127307.000000                                 None
#
#    Clients in new treatment Sex    Unit
# 0                    Opiate   T  People
# 1                    Opiate   T  People
# 2           Non-opiate only   T  People
# 3           Non-opiate only   T  People
# 4    Non-opiate and Alcohol   T  People
# 5    Non-opiate and Alcohol   T  People
# 6              Alcohol only   T  People
# 7              Alcohol only   T  People
# 8                     Total   T  People
# 9                     Total   T  People
# 10                   Opiate   T  People
# 11                   Opiate   T  People
# 12          Non-opiate only   T  People
# 13          Non-opiate only   T  People
# 14   Non-opiate and Alcohol   T  People
# 15   Non-opiate and Alcohol   T  People
# 16             Alcohol only   T  People
# 17             Alcohol only   T  People
# 18                    Total   T  People
# 19                    Total   T  People
# 20                   Opiate   T  People
# 21                   Opiate   T  People
# 22          Non-opiate only   T  People
# 23          Non-opiate only   T  People
# 24   Non-opiate and Alcohol   T  People
# 25   Non-opiate and Alcohol   T  People
# 26             Alcohol only   T  People
# 27             Alcohol only   T  People
# 28                    Total   T  People
# 29                    Total   T  People
# 30                   Opiate   T  People
# 31                   Opiate   T  People
# 32          Non-opiate only   T  People
# 33          Non-opiate only   T  People
# 34   Non-opiate and Alcohol   T  People
# 35   Non-opiate and Alcohol   T  People
# 36             Alcohol only   T  People
# 37             Alcohol only   T  People
# 38                    Total   T  People
# 39                    Total   T  People
# 40                   Opiate   T  People
# 41                   Opiate   T  People
# 42          Non-opiate only   T  People
# 43          Non-opiate only   T  People
# 44   Non-opiate and Alcohol   T  People
# 45   Non-opiate and Alcohol   T  People
# 46             Alcohol only   T  People
# 47             Alcohol only   T  People
# 48                    Total   T  People
# 49                    Total   T  People
# 50                   Opiate   T  People
# 51          Non-opiate only   T  People
# 52   Non-opiate and Alcohol   T  People
# 53             Alcohol only   T  People
# 54                    Total   T  People
# 55                   Opiate   T  People
# 56          Non-opiate only   T  People
# 57   Non-opiate and Alcohol   T  People
# 58             Alcohol only   T  People
# 59                    Total   T  People

# %%
new_table = new_table[new_table['OBS'] != 0 ]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table.head()
# Out:
#          Value              Parental status Clients in new treatment Sex  \
# 0  3919.000000  Parent living with children                   Opiate   T
# 1     0.095700  Parent living with children                   Opiate   T
# 2  3272.000000  Parent living with children          Non-opiate only   T
# 3     0.197322  Parent living with children          Non-opiate only   T
# 4  3004.000000  Parent living with children   Non-opiate and Alcohol   T
#
#      Unit
# 0  People
# 1  People
# 2  People
# 3  People
# 4  People

# %%
new_table['Value'] = new_table['Value'].astype(str)

# %%
new_table['Measure Type'] = 'Count'

# %%
new_table.tail()
# Out:
#        Value Parental status Clients in new treatment Sex    Unit Measure Type
# 55   41178.0            None                   Opiate   T  People        Count
# 56   16716.0            None          Non-opiate only   T  People        Count
# 57   18757.0            None   Non-opiate and Alcohol   T  People        Count
# 58   50656.0            None             Alcohol only   T  People        Count
# 59  127307.0            None                    Total   T  People        Count

# %%
new_table.dtypes
# Out:
# Value                       object
# Parental status             object
# Clients in new treatment    object
# Sex                         object
# Unit                        object
# Measure Type                object
# dtype: object

# %%
new_table.head(3)
# Out:
#                 Value              Parental status Clients in new treatment  \
# 0              3919.0  Parent living with children                   Opiate
# 1  0.0956997387121194  Parent living with children                   Opiate
# 2              3272.0  Parent living with children          Non-opiate only
#
#   Sex    Unit Measure Type
# 0   T  People        Count
# 1   T  People        Count
# 2   T  People        Count

# %%
new_table['Clients in new treatment'] = new_table['Clients in new treatment'].map(
    lambda x: {
        'Total' : 'All Clients' 
        }.get(x, x))

# %%
def user_perc(x):
    
    if x == None:
        return 'All inclusice incomplete data'
    else:
        return x
    
new_table['Parental status'] = new_table.apply(lambda row: user_perc(row['Parental status']), axis = 1)

# %%
new_table.head(3)
# Out:
#                 Value              Parental status Clients in new treatment  \
# 0              3919.0  Parent living with children                   Opiate
# 1  0.0956997387121194  Parent living with children                   Opiate
# 2              3272.0  Parent living with children          Non-opiate only
#
#   Sex    Unit Measure Type
# 0   T  People        Count
# 1   T  People        Count
# 2   T  People        Count

# %%
new_table['Parental status'] = new_table['Parental status'].map(
    lambda x: {
        'Total' : 'All children',
        }.get(x, x))

# %%
new_table['Parental status'] =  'Parental status/' + new_table['Parental status']
new_table['Clients in new treatment'] = 'New clients/' + new_table['Clients in new treatment']

# %%
new_table['Parental status'] =  new_table['Parental status'] +'/'+ new_table['Sex']

# %%
new_table.columns = ['Clients in treatment' if x=='Clients in new treatment' else x for x in new_table.columns]
new_table['Period'] = '2017-18'
new_table.columns = ['Basis of treatment' if x=='Parental status' else x for x in new_table.columns]
new_table['Substance'] = 'All'
new_table = new_table[['Period','Basis of treatment','Substance','Clients in treatment','Measure Type','Value','Unit']]

# %%
# if is_interactive():
#     SubstancetinationFolder = Path('out')
#     SubstancetinationFolder.mkdir(exist_ok=True, parents=True)
#     new_table.to_csv(SubstancetinationFolder / ('table4.12.1.1.csv'), index = False)

# %%
new_table.head()
# Out:
#     Period                             Basis of treatment Substance  \
# 0  2017-18  Parental status/Parent living with children/T       All
# 1  2017-18  Parental status/Parent living with children/T       All
# 2  2017-18  Parental status/Parent living with children/T       All
# 3  2017-18  Parental status/Parent living with children/T       All
# 4  2017-18  Parental status/Parent living with children/T       All
#
#                  Clients in treatment Measure Type               Value    Unit
# 0                  New clients/Opiate        Count              3919.0  People
# 1                  New clients/Opiate        Count  0.0956997387121194  People
# 2         New clients/Non-opiate only        Count              3272.0  People
# 3         New clients/Non-opiate only        Count   0.197322397780726  People
# 4  New clients/Non-opiate and Alcohol        Count              3004.0  People
