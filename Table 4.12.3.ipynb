# %% [markdown]
# Table 4.12.3: Clients' children receiving early help or in contact with children's social care

# %%
from gssutils import *

if is_interactive():
    scraper = Scraper('https://www.gov.uk/government/collections/alcohol-and-drug-misuse-and-treatment-statistics')
    scraper.select_dataset(title=lambda x: x.startswith('Substance misuse treatment for adults'), latest=True)
    tabs = {tab.name: tab for tab in scraper.distribution(title=lambda x: x.startswith('Data tables')).as_databaker()}

# %%
tab = tabs['Table 4.12.3']

# %% [markdown]
# https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/752515/AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx

# %%
cell = tab.filter("Help received or in contact with children's social care")
cell.assert_one()
obs = tab.filter('Missing').shift(0,-1).expand(RIGHT)
observations = tab.filter('n').fill(DOWN).is_not_blank().is_not_whitespace() - obs
helps = cell.expand(DOWN).is_not_blank().is_not_whitespace()
Clients = cell.expand(RIGHT).is_not_blank().is_not_whitespace()
Dimensions = [
            HDim(helps,'Treatment group',DIRECTLY,LEFT),
            HDim(Clients,'Clients in treatment',CLOSEST,LEFT),
            HDimConst('Measure Type','count-of-children'),
            HDimConst('Unit','children'),
            HDimConst('Period', 'gregorian-interval/2017-04-01T00:00:00/P1Y')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
if is_interactive():
    savepreviewhtml(c1)
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc0" style="background-color:Aqua">OBS</td><td class="xc1" style="background-color:LightGreen">Treatment group</td><td class="xc2" style="background-color:MistyRose">Clients in treatment</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Table 4.12.3</caption>
# <tr><td title="0 0">Table 4.12.3: Clients' children receiving early help or in contact with children's social care</td><td title="1 0"></td><td title="2 0"></td><td title="3 0"></td><td title="4 0"></td><td title="5 0"></td><td title="6 0"></td><td title="7 0"></td><td title="8 0"></td><td title="9 0"></td><td title="10 0"></td></tr>
# <tr><td title="0 1">Link back to the index</td><td title="1 1"></td><td title="2 1"></td><td title="3 1"></td><td title="4 1"></td><td title="5 1"></td><td title="6 1"></td><td title="7 1"></td><td title="8 1"></td><td title="9 1"></td><td title="10 1"></td></tr>
# <tr><td style="background-color:MistyRose" title="0 2">Help received or in contact with children's social care</td><td style="background-color:MistyRose" title="1 2">Opiates</td><td title="2 2"></td><td style="background-color:MistyRose" title="3 2">Non-opiates only</td><td title="4 2"></td><td style="background-color:MistyRose" title="5 2">Alcohol & non-opiates</td><td title="6 2"></td><td style="background-color:MistyRose" title="7 2">Alcohol only</td><td title="8 2"></td><td style="background-color:MistyRose" title="9 2">Total</td><td title="10 2"></td></tr>
# <tr><td title="0 3"></td><td title="1 3">n</td><td title="2 3">%</td><td title="3 3">n</td><td title="4 3">%</td><td title="5 3">n</td><td title="6 3">%</td><td title="7 3">n</td><td title="8 3">%</td><td title="9 3">n</td><td title="10 3">%</td></tr>
# <tr><td style="background-color:LightGreen" title="0 4">Early help</td><td style="background-color:Aqua" title="1 4">299.0</td><td title="2 4">0.0160925726587729</td><td style="background-color:Aqua" title="3 4">343.0</td><td title="4 4">0.0452805280528053</td><td style="background-color:Aqua" title="5 4">278.0</td><td title="6 4">0.033778857837181</td><td style="background-color:Aqua" title="7 4">779.0</td><td title="8 4">0.0372673778883414</td><td style="background-color:Aqua" title="9 4">1699.0</td><td title="10 4">0.0307299956590942</td></tr>
# <tr><td style="background-color:LightGreen" title="0 5">Child in need</td><td style="background-color:Aqua" title="1 5">390.0</td><td title="2 5">0.0209903121636168</td><td style="background-color:Aqua" title="3 5">410.0</td><td title="4 5">0.0541254125412541</td><td style="background-color:Aqua" title="5 5">311.0</td><td title="6 5">0.0377885783718104</td><td style="background-color:Aqua" title="7 5">734.0</td><td title="8 5">0.0351145768549969</td><td style="background-color:Aqua" title="9 5">1845.0</td><td title="10 5">0.0333707133555202</td></tr>
# <tr><td style="background-color:LightGreen" title="0 6">Child protection plan</td><td style="background-color:Aqua" title="1 6">1070.0</td><td title="2 6">0.0575888051668461</td><td style="background-color:Aqua" title="3 6">1125.0</td><td title="4 6">0.148514851485149</td><td style="background-color:Aqua" title="5 6">780.0</td><td title="6 6">0.094775212636695</td><td style="background-color:Aqua" title="7 6">1434.0</td><td title="8 6">0.0686025929292446</td><td style="background-color:Aqua" title="9 6">4409.0</td><td title="10 6">0.0797460570105629</td></tr>
# <tr><td style="background-color:LightGreen" title="0 7
8,5,2],"9 10":[0,10,9,2],"3 5":[0,5,3,2],"3 8":[0,8,3,2],"7 11":[0,11,7,2],"3 7":[0,7,3,2],"1 8":[0,8,1,2],"9 5":[0,5,9,2],"7 5":[0,5,7,2],"7 10":[0,10,7,2],"1 4":[0,4,1,2],"5 10":[0,10,5,2],"7 7":[0,7,7,2],"1 7":[0,7,1,2],"7 6":[0,6,7,2],"7 8":[0,8,7,2],"1 5":[0,5,1,2],"9 4":[0,4,9,2]};
# var jdividNUM = "injblock1001";
# var Dclickedcell = null;
# function clickedcell()
# {
#     Dclickedcell = this;
#     console.log("jjjj", this);
#     var rgc = new RegExp('(^|\b)' + "selected".split(' ').join('|') + '(\b|$)', 'gi');
#     Array.prototype.forEach.call(document.querySelectorAll("div#"+jdividNUM+" table.ex td.selected"), function(el, i) {
#         if (el.classList)

# %%
new_table = c1.topandas()

# %%
import numpy as np
new_table['OBS'].replace('', np.nan, inplace=True)
new_table.dropna(subset=['OBS'], inplace=True)
new_table.rename(columns={'OBS': 'Value'}, inplace=True)
new_table['Value'] = new_table['Value'].astype(int)
new_table['Value'] = new_table['Value'].map(lambda x:''
                                  if (x == '-')
                                  else int(x))

# %%
new_table["Basis of treatment"] = new_table["Treatment group"].map(
    lambda x: {
        "Help received or in contact with children's social care":"help-received-or-in-contact-with-childrens-social-care",
        'Early help':'help-received-or-in-contact-with-childrens-social-care/early-help',
        'Child in need':'help-received-or-in-contact-with-childrens-social-care/child-in-need',
        'Child protection plan':'help-received-or-in-contact-with-childrens-social-care/child-protection-plan',
        'Looked after child':'help-received-or-in-contact-with-childrens-social-care/looked-after-child',
        'No early help':'help-received-or-in-contact-with-childrens-social-care/no-early-help',
        'Missing':'help-received-or-in-contact-with-childrens-social-care/missing',
        'Total':'help-received-or-in-contact-with-childrens-social-care/total'
        }.get(x, x))

# %%
new_table["Substance type"] = new_table['Clients in treatment'].map(
    lambda x: {
        'Opiates' : 'opiate', 
        'Non-opiates only' : 'non-opiate-only', 
        'Alcohol & non-opiates' : 'non-opiate-and-alcohol',
        'Alcohol only' : 'alcohol-only', 
        'Total' : 'total'
                }.get(x, x))

# %%
new_table = new_table[['Period','Basis of treatment','Substance type','Measure Type','Value','Unit']]

# %%
new_table
# Out:
#                                         Period  \
# 0   gregorian-interval/2017-04-01T00:00:00/P1Y
# 1   gregorian-interval/2017-04-01T00:00:00/P1Y
# 2   gregorian-interval/2017-04-01T00:00:00/P1Y
# 3   gregorian-interval/2017-04-01T00:00:00/P1Y
# 4   gregorian-interval/2017-04-01T00:00:00/P1Y
# 5   gregorian-interval/2017-04-01T00:00:00/P1Y
# 6   gregorian-interval/2017-04-01T00:00:00/P1Y
# 7   gregorian-interval/2017-04-01T00:00:00/P1Y
# 8   gregorian-interval/2017-04-01T00:00:00/P1Y
# 9   gregorian-interval/2017-04-01T00:00:00/P1Y
# 10  gregorian-interval/2017-04-01T00:00:00/P1Y
# 11  gregorian-interval/2017-04-01T00:00:00/P1Y
# 12  gregorian-interval/2017-04-01T00:00:00/P1Y
# 13  gregorian-interval/2017-04-01T00:00:00/P1Y
# 14  gregorian-interval/2017-04-01T00:00:00/P1Y
# 15  gregorian-interval/2017-04-01T00:00:00/P1Y
# 16  gregorian-interval/2017-04-01T00:00:00/P1Y
# 17  gregorian-interval/2017-04-01T00:00:00/P1Y
# 18  gregorian-interval/2017-04-01T00:00:00/P1Y
# 19  gregorian-interval/2017-04-01T00:00:00/P1Y
# 20  gregorian-interval/2017-04-01T00:00:00/P1Y
# 21  gregorian-interval/2017-04-01T00:00:00/P1Y
# 22  gregorian-interval/2017-04-01T00:00:00/P1Y
# 23  gregorian-interval/2017-04-01T00:00:00/P1Y
# 24  gregorian-interval/2017-04-01T00:00:00/P1Y
# 25  gregorian-interval/2017-04-01T00:00:00/P1Y
# 26  gregorian-interval/2017-04-01T00:00:00/P1Y
# 27  gregorian-interval/2017-04-01T00:00:00/P1Y
# 28  gregorian-interval/2017-04-01T00:00:00/P1Y
# 29  gregorian-interval/2017-04-01T00:00:00/P1Y
# 30  gregorian-interval/2017-04-01T00:00:00/P1Y
# 31  gregorian-interval/2017-04-01T00:00:00/P1Y
# 32  gregorian-interval/2017-04-01T00:00:00/P1Y
# 33  gregorian-interval/2017-04-01T00:00:00/P1Y
# 34  gregorian-interval/2017-04-01T00:00:00/P1Y
#
#                                    Basis of treatment          Substance type  \
# 0   help-received-or-in-contact-with-childrens-soc...                  opiate
# 1   help-received-or-in-contact-with-childrens-soc...         non-opiate-only
# 2   help-received-or-in-contact-with-childrens-soc...  non-opiate-and-alcohol
# 3   help-received-or-in-contact-with-childrens-soc...            alcohol-only
# 4   help-received-or-in-contact-with-childrens-soc...                   total
# 5   help-received-or-in-contact-with-childrens-soc...                  opiate
# 6   help-received-or-in-contact-with-childrens-soc...         non-opiate-only
# 7   help-received-or-in-contact-with-childrens-soc...  non-opiate-and-alcohol
# 8   help-received-or-in-contact-with-childrens-soc...            alcohol-only
# 9   help-received-or-in-contact-with-childrens-soc...                   total
# 10  help-received-or-in-contact-with-childrens-soc...                  opiate
# 11  help-received-or-in-contact-with-childrens-soc...         non-opiate-only
# 12  help-received-or-in-contact-with-childrens-soc...  non-opiate-and-alcohol
# 13  help-received-or-in-contact-with-childrens-soc...            alcohol-only
# 14  help-received-or-in-contact-with-childrens-soc...                   total
# 15  help-received-or-in-contact-with-childrens-soc...                  opiate
# 16  help-received-or-in-contact-with-childrens-soc...         non-opiate-only
# 17  help-received-or-in-contact-with-childrens-soc...  non-opiate-and-alcohol
# 18  help-received-or-in-contact-with-childrens-soc...            alcohol-only
# 19  help-received-or-in-contact-with-childrens-soc...                   total
# 20  help-received-or-in-contact-with-childrens-soc...                  opiate
# 21  help-received-or-in-contact-with-childrens-soc...         non-opiate-only
# 22  help-received-or-in-contact-with-childrens-soc...  non-opiate-and-alcohol
# 23  help-received-or-in-contact-with-childrens-soc...            alcohol-only
# 24  help-received-or-in-contact-with-childrens-soc...                   total
# 25  help-received-or-in-contact-with-childrens-soc...                  opiate
# 26  help-received-or-in-contact-with-childrens-soc...         non-opiate-only
# 27  help-received-or-in-contact-with-childrens-soc...  non-opiate-and-alcohol
# 28  help-received-or-in-contact-with-childrens-soc...            alcohol-only
# 29  help-received-or-in-contact-with-childrens-soc...                   total
# 30  help-received-or-in-contact-with-childrens-soc...                  opiate
# 31  help-received-or-in-contact-with-childrens-soc...         non-opiate-only
# 32  help-received-or-in-contact-with-childrens-soc...  non-opiate-and-alcohol
# 33  help-received-or-in-contact-with-childrens-soc...            alcohol-only
# 34  help-received-or-in-contact-with-childrens-soc...                   total
#
#    Measure Type  Value      Unit
# 0         Count    299  children
# 1         Count    343  children
# 2         Count    278  children
# 3         Count    779  children
# 4         Count   1699  children
# 5         Count    390  children
# 6         Count    410  children
# 7         Count    311  children
# 8         Count    734  children
# 9         Count   1845  children
# 10        Count   1070  children
# 11        Count   1125  children
# 12        Count    780  children
# 13        Count   1434  children
# 14        Count   4409  children
# 15        Count   1287  children
# 16        Count    460  children
# 17        Count    368  children
# 18        Count    573  children
# 19        Count   2688  children
# 20        Count  15534  children
# 21        Count   5237  children
# 22        Count   6493  children
# 23        Count  17383  children
# 24        Count  44647  children
# 25        Count   3005  children
# 26        Count   1053  children
# 27        Count   1129  children
# 28        Count   3970  children
# 29        Count   9157  children
# 30        Count  21585  children
# 31        Count   8628  children
# 32        Count   9359  children
# 33        Count  24873  children
# 34        Count  64445  children
