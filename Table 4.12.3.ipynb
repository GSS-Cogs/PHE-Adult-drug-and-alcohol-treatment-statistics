# %% [markdown]
# Table 4.12.3: Clients' children receiving early help or in contact with children's social care

# %%
from gssutils import *

if is_interactive():
    scraper = Scraper('https://www.gov.uk/government/collections/alcohol-and-drug-misuse-and-treatment-statistics')
    scraper.select_dataset(title=lambda x: x.startswith('Substance misuse treatment for adults'), latest=True)
    tabs = {tab.name: tab for tab in scraper.distribution(title=lambda x: x.startswith('Data tables')).as_databaker()}

# %%
tab = tabs['Table 4.12.3']

# %% [markdown]
# https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/752515/AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx

# %%
cell = tab.filter("Help received or in contact with children's social care")
cell.assert_one()
observations = tab.filter('n').fill(DOWN).is_not_blank().is_not_whitespace()
helps = cell.expand(DOWN).is_not_blank().is_not_whitespace()
Clients = cell.expand(RIGHT).is_not_blank().is_not_whitespace()
Dimensions = [
            HDim(helps,'Treatment group',DIRECTLY,LEFT),
            HDim(Clients,'Clients in treatment',CLOSEST,LEFT),
            HDimConst('Measure Type','Count'),
            HDimConst('Unit','Children in treatment'),
            HDimConst('Period', '2018-03-31T00:00:00/P1Y'),
            HDimConst('Basis of treatment','children care')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
if is_interactive():
    savepreviewhtml(c1)
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc0" style="background-color:Aqua">OBS</td><td class="xc1" style="background-color:LightGreen">Treatment group</td><td class="xc2" style="background-color:MistyRose">Clients in treatment</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Table 4.12.3</caption>
# <tr><td title="0 0">Table 4.12.3: Clients' children receiving early help or in contact with children's social care</td><td title="1 0"></td><td title="2 0"></td><td title="3 0"></td><td title="4 0"></td><td title="5 0"></td><td title="6 0"></td><td title="7 0"></td><td title="8 0"></td><td title="9 0"></td><td title="10 0"></td></tr>
# <tr><td title="0 1">Link back to the index</td><td title="1 1"></td><td title="2 1"></td><td title="3 1"></td><td title="4 1"></td><td title="5 1"></td><td title="6 1"></td><td title="7 1"></td><td title="8 1"></td><td title="9 1"></td><td title="10 1"></td></tr>
# <tr><td style="background-color:MistyRose" title="0 2">Help received or in contact with children's social care</td><td style="background-color:MistyRose" title="1 2">Opiates</td><td title="2 2"></td><td style="background-color:MistyRose" title="3 2">Non-opiates only</td><td title="4 2"></td><td style="background-color:MistyRose" title="5 2">Alcohol & non-opiates</td><td title="6 2"></td><td style="background-color:MistyRose" title="7 2">Alcohol only</td><td title="8 2"></td><td style="background-color:MistyRose" title="9 2">Total</td><td title="10 2"></td></tr>
# <tr><td title="0 3"></td><td title="1 3">n</td><td title="2 3">%</td><td title="3 3">n</td><td title="4 3">%</td><td title="5 3">n</td><td title="6 3">%</td><td title="7 3">n</td><td title="8 3">%</td><td title="9 3">n</td><td title="10 3">%</td></tr>
# <tr><td style="background-color:LightGreen" title="0 4">Early help</td><td style="background-color:Aqua" title="1 4">299.0</td><td title="2 4">0.0160925726587729</td><td style="background-color:Aqua" title="3 4">343.0</td><td title="4 4">0.0452805280528053</td><td style="background-color:Aqua" title="5 4">278.0</td><td title="6 4">0.033778857837181</td><td style="background-color:Aqua" title="7 4">779.0</td><td title="8 4">0.0372673778883414</td><td style="background-color:Aqua" title="9 4">1699.0</td><td title="10 4">0.0307299956590942</td></tr>
# <tr><td style="background-color:LightGreen" title="0 5">Child in need</td><td style="background-color:Aqua" title="1 5">390.0</td><td title="2 5">0.0209903121636168</td><td style="background-color:Aqua" title="3 5">410.0</td><td title="4 5">0.0541254125412541</td><td style="background-color:Aqua" title="5 5">311.0</td><td title="6 5">0.0377885783718104</td><td style="background-color:Aqua" title="7 5">734.0</td><td title="8 5">0.0351145768549969</td><td style="background-color:Aqua" title="9 5">1845.0</td><td title="10 5">0.0333707133555202</td></tr>
# <tr><td style="background-color:LightGreen" title="0 6">Child protection plan</td><td style="background-color:Aqua" title="1 6">1070.0</td><td title="2 6">0.0575888051668461</td><td style="background-color:Aqua" title="3 6">1125.0</td><td title="4 6">0.148514851485149</td><td style="background-color:Aqua" title="5 6">780.0</td><td title="6 6">0.094775212636695</td><td style="background-color:Aqua" title="7 6">1434.0</td><td title="8 6">0.0686025929292446</td><td style="background-color:Aqua" title="9 6">4409.0</td><td title="10 6">0.0797460570105629</td></tr>
# <tr><td style="background-color:LightGreen" title="0 7
# var jslookup = {"5 7":[0,7,5,2],"9 4":[0,4,9,2],"5 6":[0,6,5,2],"1 10":[0,10,1,2],"3 4":[0,4,3,2],"5 5":[0,5,5,2],"3 10":[0,10,3,2],"5 4":[0,4,5,2],"5 11":[0,11,5,2],"1 11":[0,11,1,2],"7 4":[0,4,7,2],"9 9":[0,9,9,2],"7 9":[0,9,7,2],"1 6":[0,6,1,2],"9 11":[0,11,9,2],"9 7":[0,7,9,2],"9 6":[0,6,9,2],"3 11":[0,11,3,2],"3 6":[0,6,3,2],"9 10":[0,10,9,2],"3 5":[0,5,3,2],"9 8":[0,8,9,2],"7 11":[0,11,7,2],"5 8":[0,8,5,2],"7 5":[0,5,7,2],"7 10":[0,10,7,2],"3 8":[0,8,3,2],"1 9":[0,9,1,2],"7 7":[0,7,7,2],"3 7":[0,7,3,2],"1 8":[0,8,1,2],"9 5":[0,5,9,2],"5 9":[0,9,5,2],"1 4":[0,4,1,2],"5 10":[0,10,5,2],"1 7":[0,7,1,2],"1 5":[0,5,1,2],"3 9":[0,9,3,2],"7 6":[0,6,7,2],"7 8":[0,8,7,2]};
# var jdividNUM = "injblock1001";
# var Dclickedcell = null;
# function clickedcell()
# {
#     Dclickedcell = this;
#     console.log("jjjj", this);
#     va

# %%
new_table = c1.topandas()

# %%
import numpy as np
new_table['OBS'].replace('', np.nan, inplace=True)
new_table.dropna(subset=['OBS'], inplace=True)
new_table.rename(columns={'OBS': 'Value'}, inplace=True)
new_table['Value'] = new_table['Value'].astype(int)
new_table['Value'] = new_table['Value'].map(lambda x:''
                                  if (x == '-')
                                  else int(x))

# %%
new_table["Treatment group"] = new_table["Treatment group"].map(
    lambda x: {
        'Total' : 'All types of care' 
        }.get(x, x))

# %%
def user_perc(x):
    
    if x == None:
        return 'All inclusice missing'
    else:
        return x
    
new_table["Treatment group"] = new_table.apply(lambda row: user_perc(row["Treatment group"]), axis = 1)

# %%
new_table['Clients in treatment'] = new_table['Clients in treatment'].map(
    lambda x: {
        'Total' : 'All Clients',
        }.get(x, x))

# %%
new_table = new_table[['Period','Basis of treatment','Treatment group','Clients in treatment','Measure Type','Value','Unit']]

# %%
new_table
# Out:
#                      Period Basis of treatment        Treatment group  \
# 0   2018-03-31T00:00:00/P1Y      children care             Early help
# 1   2018-03-31T00:00:00/P1Y      children care             Early help
# 2   2018-03-31T00:00:00/P1Y      children care             Early help
# 3   2018-03-31T00:00:00/P1Y      children care             Early help
# 4   2018-03-31T00:00:00/P1Y      children care             Early help
# 5   2018-03-31T00:00:00/P1Y      children care          Child in need
# 6   2018-03-31T00:00:00/P1Y      children care          Child in need
# 7   2018-03-31T00:00:00/P1Y      children care          Child in need
# 8   2018-03-31T00:00:00/P1Y      children care          Child in need
# 9   2018-03-31T00:00:00/P1Y      children care          Child in need
# 10  2018-03-31T00:00:00/P1Y      children care  Child protection plan
# 11  2018-03-31T00:00:00/P1Y      children care  Child protection plan
# 12  2018-03-31T00:00:00/P1Y      children care  Child protection plan
# 13  2018-03-31T00:00:00/P1Y      children care  Child protection plan
# 14  2018-03-31T00:00:00/P1Y      children care  Child protection plan
# 15  2018-03-31T00:00:00/P1Y      children care     Looked after child
# 16  2018-03-31T00:00:00/P1Y      children care     Looked after child
# 17  2018-03-31T00:00:00/P1Y      children care     Looked after child
# 18  2018-03-31T00:00:00/P1Y      children care     Looked after child
# 19  2018-03-31T00:00:00/P1Y      children care     Looked after child
# 20  2018-03-31T00:00:00/P1Y      children care          No early help
# 21  2018-03-31T00:00:00/P1Y      children care          No early help
# 22  2018-03-31T00:00:00/P1Y      children care          No early help
# 23  2018-03-31T00:00:00/P1Y      children care          No early help
# 24  2018-03-31T00:00:00/P1Y      children care          No early help
# 25  2018-03-31T00:00:00/P1Y      children care      All types of care
# 26  2018-03-31T00:00:00/P1Y      children care      All types of care
# 27  2018-03-31T00:00:00/P1Y      children care      All types of care
# 28  2018-03-31T00:00:00/P1Y      children care      All types of care
# 29  2018-03-31T00:00:00/P1Y      children care      All types of care
# 30  2018-03-31T00:00:00/P1Y      children care                Missing
# 31  2018-03-31T00:00:00/P1Y      children care                Missing
# 32  2018-03-31T00:00:00/P1Y      children care                Missing
# 33  2018-03-31T00:00:00/P1Y      children care                Missing
# 34  2018-03-31T00:00:00/P1Y      children care                Missing
# 35  2018-03-31T00:00:00/P1Y      children care      All types of care
# 36  2018-03-31T00:00:00/P1Y      children care      All types of care
# 37  2018-03-31T00:00:00/P1Y      children care      All types of care
# 38  2018-03-31T00:00:00/P1Y      children care      All types of care
# 39  2018-03-31T00:00:00/P1Y      children care      All types of care
#
#      Clients in treatment Measure Type  Value                   Unit
# 0                 Opiates        Count    299  Children in treatment
# 1        Non-opiates only        Count    343  Children in treatment
# 2   Alcohol & non-opiates        Count    278  Children in treatment
# 3            Alcohol only        Count    779  Children in treatment
# 4             All Clients        Count   1699  Children in treatment
# 5                 Opiates        Count    390  Children in treatment
# 6        Non-opiates only        Count    410  Children in treatment
# 7   Alcohol & non-opiates        Count    311  Children in treatment
# 8            Alcohol only        Count    734  Children in treatment
# 9             All Clients        Count   1845  Children in treatment
# 10                Opiates        Count   1070  Children in treatment
# 11       Non-opiates only        Count   1125  Children in treatment
# 12  Alcohol & non-opiates        Count    780  Children in treatment
# 13           Alcohol only        Count   1434  Children in treatment
# 14            All Clients        Count   4409  Children in treatment
# 15                Opiates        Count   1287  Children in treatment
# 16       Non-opiates only        Count    460  Children in treatment
# 17  Alcohol & non-opiates        Count    368  Children in treatment
# 18           Alcohol only        Count    573  Children in treatment
# 19            All Clients        Count   2688  Children in treatment
# 20                Opiates        Count  15534  Children in treatment
# 21       Non-opiates only        Count   5237  Children in treatment
# 22  Alcohol & non-opiates        Count   6493  Children in treatment
# 23           Alcohol only        Count  17383  Children in treatment
# 24            All Clients        Count  44647  Children in treatment
# 25                Opiates        Count  18580  Children in treatment
# 26       Non-opiates only        Count   7575  Children in treatment
# 27  Alcohol & non-opiates        Count   8230  Children in treatment
# 28           Alcohol only        Count  20903  Children in treatment
# 29            All Clients        Count  55288  Children in treatment
# 30                Opiates        Count   3005  Children in treatment
# 31       Non-opiates only        Count   1053  Children in treatment
# 32  Alcohol & non-opiates        Count   1129  Children in treatment
# 33           Alcohol only        Count   3970  Children in treatment
# 34            All Clients        Count   9157  Children in treatment
# 35                Opiates        Count  21585  Children in treatment
# 36       Non-opiates only        Count   8628  Children in treatment
# 37  Alcohol & non-opiates        Count   9359  Children in treatment
# 38           Alcohol only        Count  24873  Children in treatment
# 39            All Clients        Count  64445  Children in treatment
