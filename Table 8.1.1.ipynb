# %% [markdown]
# Table 8.1.1: Treatment contact status at 31st March 2018 by main substance groups for clients commencing treatment since 2005-06

# %%
from gssutils import *

if is_interactive():
    import requests
    from cachecontrol import CacheControl
    from cachecontrol.caches.file_cache import FileCache
    from cachecontrol.heuristics import LastModified
    from pathlib import Path

    session = CacheControl(requests.Session(),
                           cache=FileCache('.cache'),
                           heuristic=LastModified())

    sourceFolder = Path('in')
    sourceFolder.mkdir(exist_ok=True)

    inputURL = 'https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/752515/AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx'
    inputFile = sourceFolder / 'AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx'
    response = session.get(inputURL)
    with open(inputFile, 'wb') as f:
      f.write(response.content)

# %%
tab = loadxlstabs(inputFile, sheetids='Table 8.1.1')[0]
# Out:
# Loading in\AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx which has size 272149 bytes
# Table names: ['Table 8.1.1']

# %% [markdown]
# https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/752515/AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx

# %%
observations = tab.excel_ref('B6').expand(DOWN).expand(RIGHT).is_not_blank()
observations
# Out:
# {<P16 11677.0>, <O6 3316.0>, <D19 11755.0>, <E19 14071.0>, <E27 32948.0>, <L26 4274.0>, <G14 8011.0>, <Q11 0.03843066776011586>, <O22 4722.0>, <P8 77000.0>, <M12 3370.0>, <H29 65532.0>, <D16 529.0>, <D8 8555.0>, <O7 1279.0>, <J11 73.0>, <F29 82441.0>, <E17 6149.0>, <H16 661.0>, <L29 53119.0>, <I7 4339.0>, <H17 4904.0>, <M11 204.0>, <F21 896.0>, <N11 402.0>, <O19 8311.0>, <M13 5620.0>, <H28 34913.0>, <F24 34927.0>, <I18 6676.0>, <E12 4508.0>, <J9 9070.0>, <B14 4047.0>, <I24 29081.0>, <Q18 0.517062286000077>, <B28 25764.0>, <G18 7755.0>, <F26 8273.0>, <C23 7241.0>, <D13 3502.0>, <Q12 0.4066409589782066>, <D6 10463.0>, <B26 34483.0>, <F17 6827.0>, <O8 680.0>, <P26 140070.0>, <H21 819.0>, <I28 32970.0>, <C24 16274.0>, <D9 33577.0>, <N9 6355.0>, <E22 10833.0>, <B13 1588.0>, <G22 14205.0>, <M24 25572.0>, <K24 29481.0>, <O26 18314.0>, <G23 18119.0>, <O24 21579.0>, <Q9 1.0>, <K26 4525.0>, <C21 327.0>, <H9 13620.0>, <J18 6156.0>, <F22 15637.0>, <L11 129.0>, <D7 14559.0>, <C8 11868.0>, <F7 9808.0>, <Q26 0.1522792972126159>, <J29 57188.0>, <H13 5050.0>, <B22 3902.0>, <E18 7243.0>, <K27 21070.0>, <C28 27489.0>, <E28 32149.0>, <O16 3220.0>, <L24 26949.0>, <F18 8463.0>, <N21 1909.0>, <K22 10308.0>, <B21 174.0>, <K18 6042.0>, <B27 36641.0>, <L17 3742.0>, <P22 134650.0>, <P7 119130.0>, <K28 32617.0>, <K29 58212.0>, <F23 18394.0>, <D11 44.0>, <J6 2657.0>, <G28 36066.0>, <L22 9168.0>, <G26 6522.0>, <L28 29817.0>, <F19 16116.0>, <K13 5997.0>, <Q24 1.0>, <D17 5395.0>, <G16 732.0>, <K6 2627.0>, <N13 5131.0>, <J8 2697.0>, <G11 44.0>, <M26 4778.0>, <F27 36027.0>, <Q14 1.0>, <J14 8513.0>, <P11 4405.0>, <D22 8345.0>, <L27 19028.0>, <I14 7969.0>, <O12 2356.0>, <M22 8535.0>, <C13 3003.0>, <H14 7688.0>, <F16 826.0>, <N17 3502.0>, <M6 2481.0>, <I8 3286.0>, <
# %%
treatmentstatus = tab.excel_ref('A6').expand(DOWN).is_not_blank() - clients
treatmentstatus
# Out:
# {<A28 'Subtotal treatment complete'>, <A13 'Subtotal treatment complete'>, <A8 'Subtotal treatment complete'>, <A16 'Retained at 31st March 2017'>, <A27 'Subtotal exited (treatment incomplete)'>, <A17 'Subtotal exited (treatment incomplete)'>, <A9 'Total clients in treatment since 1st April 2005'>, <A26 'Retained at 31st March 2017'>, <A14 'Total clients in treatment since 1st April 2005'>, <A22 'Subtotal exited (treatment incomplete)'>, <A21 'Retained at 31st March 2017'>, <A11 'Retained at 31st March 2017'>, <A7 'Subtotal exited (treatment incomplete)'>, <A12 'Subtotal exited (treatment incomplete)'>, <A19 'Total clients in treatment since 1st April 2005'>, <A18 'Subtotal treatment complete'>, <A24 'Total clients in treatment since 1st April 2005'>, <A6 'Retained at 31st March 2017'>, <A23 'Subtotal treatment complete'>, <A29 'Total clients in treatment since 1st April 2005'>}

# %%
period = tab.excel_ref('B4').expand(RIGHT).is_not_blank() 
period
# Out:
# {<F4 '2008-09'>, <E4 '2007-08'>, <I4 '2011-12'>, <G4 '2009-10'>, <C4 '2005-06'>, <M4 '2015-16'>, <P4 'Total'>, <B4 'Prior to 2005-06'>, <Q4 '%'>, <L4 '2014-15'>, <H4 '2010-11'>, <K4 '2013-14'>, <D4 '2006-07'>, <O4 '2017-18'>, <J4 '2012-13'>, <N4 '2016-17'>}

# %%
Dimensions = [
            HDim(clients,'Clients in treatment',CLOSEST,ABOVE),
            HDimConst('Measure Type','Count'),
            HDim(treatmentstatus, 'Treatment Status',DIRECTLY,LEFT),
            HDim(period, 'Period',DIRECTLY,ABOVE),
            HDimConst('Unit','People')            
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# if is_interactive():
#     savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#                OBS Clients in treatment Measure Type  \
# 0     33985.000000       Opiate clients        Count
# 1     17654.000000       Opiate clients        Count
# 2     10463.000000       Opiate clients        Count
# 3      7824.000000       Opiate clients        Count
# 4      6497.000000       Opiate clients        Count
# 5      4875.000000       Opiate clients        Count
# 6      3660.000000       Opiate clients        Count
# 7      2862.000000       Opiate clients        Count
# 8      2657.000000       Opiate clients        Count
# 9      2627.000000       Opiate clients        Count
# 10     2391.000000       Opiate clients        Count
# 11     2481.000000       Opiate clients        Count
# 12     2628.000000       Opiate clients        Count
# 13     3316.000000       Opiate clients        Count
# 14   103920.000000       Opiate clients        Count
# 15        0.346342       Opiate clients        Count
# 16    27823.000000       Opiate clients        Count
# 17    21008.000000       Opiate clients        Count
# 18    14559.000000       Opiate clients        Count
# 19    11458.000000       Opiate clients        Count
# 20     9808.000000       Opiate clients        Count
# 21     7697.000000       Opiate clients        Count
# 22     5671.000000       Opiate clients        Count
# 23     4339.000000       Opiate clients        Count
# 24     3716.000000       Opiate clients        Count
# 25     3595.000000       Opiate clients        Count
# 26     3181.000000       Opiate clients        Count
# 27     2749.000000       Opiate clients        Count
# 28     2247.000000       Opiate clients        Count
# 29     1279.000000       Opiate clients        Count
# ..             ...                  ...          ...
# 290   26371.000000        Total clients        Count
# 291   32149.000000        Total clients        Count
# 292   38141.000000        Total clients        Count
# 293   36066.000000        Total clients        Count
# 294   34913.000000        Total clients        Count
# 295   32970.000000        Total clients        Count
# 296   32056.000000        Total clients        Count
# 297   32617.000000        Total clients        Count
# 298   29817.000000        Total clients        Count
# 299   28106.000000        Total clients        Count
# 300   24566.000000        Total clients        Count
# 301   14697.000000        Total clients        Count
# 302  415722.000000        Total clients        Count
# 303       0.451959        Total clients        Count
# 304   96888.000000        Total clients        Count
# 305   87005.000000        Total clients        Count
# 306   70873.000000        Total clients        Count
# 307   74246.000000        Total clients        Count
# 308   82441.000000        Total clients        Count
# 309   73408.000000        Total clients        Count
# 310   65532.000000        Total clients        Count
# 311   59284.000000        Total clients        Count
# 312   57188.000000        Total clients        Count
# 313   58212.000000        Total clients        Count
# 314   53119.000000        Total clients        Count
# 315   51293.000000        Total clients        Count
# 316   46614.000000        Total clients        Count
# 317   43720.000000        Total clients        Count
# 318  919823.000000        Total clients        Count
# 319       1.000000        Total clients        Count
#
#                                     Treatment Status            Period    Unit
# 0                        Retained at 31st March 2017  Prior to 2005-06  People
# 1                        Retained at 31st March 2017           2005-06  People
# 2                        Retained at 31st March 2017           2006-07  People
# 3                        Retained at 31st March 2017           2007-08  People
# 4                        Retained at 31st March 2017           2008-09  People
# 5                        Retained at 31st March 2017           2009-10  People
# 6                        Retained at 31st March 2017           2010-11  People
# 7                        Retained at 31st March 2017           2011-12  People
# 8                        Retained at 31st March 2017           2012-13  People
# 9                        Retained at 31st March 2017           2013-14  People
# 10                       Retained at 31st March 2017           2014-15  People
# 11                       Retained at 31st March 2017           2015-16  People
# 12                       Retained at 31st March 2017           2016-17  People
# 13                       Retained at 31st March 2017           2017-18  People
# 14                       Retained at 31st March 2017             Total  People
# 15                       Retained at 31st March 2017                 %  People
# 16            Subtotal exited (treatment incomplete)  Prior to 2005-06  People
# 17            Subtotal exited (treatment incomplete)           2005-06  People
# 18            Subtotal exited (treatment incomplete)           2006-07  People
# 19            Subtotal exited (treatment incomplete)           2007-08  People
# 20            Subtotal exited (treatment incomplete)           2008-09  People
# 21            Subtotal exited (treatment incomplete)           2009-10  People
# 22            Subtotal exited (treatment incomplete)           2010-11  People
# 23            Subtotal exited (treatment incomplete)           2011-12  People
# 24            Subtotal exited (treatment incomplete)           2012-13  People
# 25            Subtotal exited (treatment incomplete)           2013-14  People
# 26            Subtotal exited (treatment incomplete)           2014-15  People
# 27            Subtotal exited (treatment incomplete)           2015-16  People
# 28            Subtotal exited (treatment incomplete)           2016-17  People
# 29            Subtotal exited (treatment incomplete)           2017-18  People
# ..                                               ...               ...     ...
# 290                      Subtotal treatment complete           2006-07  People
# 291                      Subtotal treatment complete           2007-08  People
# 292                      Subtotal treatment complete           2008-09  People
# 293                      Subtotal treatment complete           2009-10  People
# 294                      Subtotal treatment complete           2010-11  People
# 295                      Subtotal treatment complete           2011-12  People
# 296                      Subtotal treatment complete           2012-13  People
# 297                      Subtotal treatment complete           2013-14  People
# 298                      Subtotal treatment complete           2014-15  People
# 299                      Subtotal treatment complete           2015-16  People
# 300                      Subtotal treatment complete           2016-17  People
# 301                      Subtotal treatment complete           2017-18  People
# 302                      Subtotal treatment complete             Total  People
# 303                      Subtotal treatment complete                 %  People
# 304  Total clients in treatment since 1st April 2005  Prior to 2005-06  People
# 305  Total clients in treatment since 1st April 2005           2005-06  People
# 306  Total clients in treatment since 1st April 2005           2006-07  People
# 307  Total clients in treatment since 1st April 2005           2007-08  People
# 308  Total clients in treatment since 1st April 2005           2008-09  People
# 309  Total clients in treatment since 1st April 2005           2009-10  People
# 310  Total clients in treatment since 1st April 2005           2010-11  People
# 311  Total clients in treatment since 1st April 2005           2011-12  People
# 312  Total clients in treatment since 1st April 2005           2012-13  People
# 313  Total clients in treatment since 1st April 2005           2013-14  People
# 314  Total clients in treatment since 1st April 2005           2014-15  People
# 315  Total clients in treatment since 1st April 2005           2015-16  People
# 316  Total clients in treatment since 1st April 2005           2016-17  People
# 317  Total clients in treatment since 1st April 2005           2017-18  People
# 318  Total clients in treatment since 1st April 2005             Total  People
# 319  Total clients in treatment since 1st April 2005                 %  People
#
# [320 rows x 6 columns]

# %%
new_table = new_table[new_table['OBS'] != 0 ]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table.head()
# Out:
#      Value Clients in treatment Measure Type             Treatment Status  \
# 0  33985.0       Opiate clients        Count  Retained at 31st March 2017
# 1  17654.0       Opiate clients        Count  Retained at 31st March 2017
# 2  10463.0       Opiate clients        Count  Retained at 31st March 2017
# 3   7824.0       Opiate clients        Count  Retained at 31st March 2017
# 4   6497.0       Opiate clients        Count  Retained at 31st March 2017
#
#              Period    Unit
# 0  Prior to 2005-06  People
# 1           2005-06  People
# 2           2006-07  People
# 3           2007-08  People
# 4           2008-09  People

# %%
new_table['Measure Type'].unique()
# Out:
# array(['Count'], dtype=object)

# %%
new_table.tail()
# Out:
#         Value Clients in treatment Measure Type  \
# 315   51293.0        Total clients        Count
# 316   46614.0        Total clients        Count
# 317   43720.0        Total clients        Count
# 318  919823.0        Total clients        Count
# 319       1.0        Total clients        Count
#
#                                     Treatment Status   Period    Unit
# 315  Total clients in treatment since 1st April 2005  2015-16  People
# 316  Total clients in treatment since 1st April 2005  2016-17  People
# 317  Total clients in treatment since 1st April 2005  2017-18  People
# 318  Total clients in treatment since 1st April 2005    Total  People
# 319  Total clients in treatment since 1st April 2005        %  People

# %%
new_table.dtypes
# Out:
# Value                   float64
# Clients in treatment     object
# Measure Type             object
# Treatment Status         object
# Period                   object
# Unit                     object
# dtype: object

# %%
new_table['Value'] = new_table['Value'].astype(str)

# %%
new_table.head(3)
# Out:
#      Value Clients in treatment Measure Type             Treatment Status  \
# 0  33985.0       Opiate clients        Count  Retained at 31st March 2017
# 1  17654.0       Opiate clients        Count  Retained at 31st March 2017
# 2  10463.0       Opiate clients        Count  Retained at 31st March 2017
#
#              Period    Unit
# 0  Prior to 2005-06  People
# 1           2005-06  People
# 2           2006-07  People

# %%
def user_perc(x,y):
    
    if str(x) == '%':
        return 'Percentage'
    else:
        return y
    
new_table['Measure Type'] = new_table.apply(lambda row: user_perc(row['Period'],row['Measure Type']), axis = 1)

# %%
new_table['Period'] = new_table['Period'].map(
    lambda x: {
        'Total' : 'All years',
        '%'     : 'All years'
        }.get(x, x))

# %%
new_table.tail()
# Out:
#         Value Clients in treatment Measure Type  \
# 315   51293.0        Total clients        Count
# 316   46614.0        Total clients        Count
# 317   43720.0        Total clients        Count
# 318  919823.0        Total clients        Count
# 319       1.0        Total clients   Percentage
#
#                                     Treatment Status     Period    Unit
# 315  Total clients in treatment since 1st April 2005    2015-16  People
# 316  Total clients in treatment since 1st April 2005    2016-17  People
# 317  Total clients in treatment since 1st April 2005    2017-18  People
# 318  Total clients in treatment since 1st April 2005  All years  People
# 319  Total clients in treatment since 1st April 2005  All years  People

# %%
new_table = new_table[['Period','Treatment Status','Clients in treatment','Measure Type','Value','Unit']]

# %%
if is_interactive():
    SubstancetinationFolder = Path('out')
    SubstancetinationFolder.mkdir(exist_ok=True, parents=True)
    new_table.to_csv(SubstancetinationFolder / ('table8.1.1.csv'), index = False)
