# %% [markdown]
# Table 5.2.4: Length of time in prescribing for clients in continuous prescribing treatment

# %%
from gssutils import *

if is_interactive():
    import requests
    from cachecontrol import CacheControl
    from cachecontrol.caches.file_cache import FileCache
    from cachecontrol.heuristics import LastModified
    from pathlib import Path

    session = CacheControl(requests.Session(),
                           cache=FileCache('.cache'),
                           heuristic=LastModified())

    sourceFolder = Path('in')
    sourceFolder.mkdir(exist_ok=True)

    inputURL = 'https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/752515/AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx'
    inputFile = sourceFolder / 'AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx'
    response = session.get(inputURL)
    with open(inputFile, 'wb') as f:
      f.write(response.content)

# %%
tab = loadxlstabs(inputFile, sheetids='Table 5.2.4')[0]
# Out:
# Loading in\AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx which has size 272149 bytes
# Table names: ['Table 5.2.4']

# %% [markdown]
# https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/752515/AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx

# %%
observations = tab.excel_ref('B5').expand(DOWN).expand(RIGHT).is_not_blank()
observations
# Out:
# {<I7 0.01>, <F10 27.0>, <B9 6801.0>, <G6 0.05>, <K11 1.0>, <K7 0.1>, <B8 11363.0>, <H11 14805.0>, <I5 0.93>, <K9 0.05>, <C10 0.22>, <G8 0.01>, <B6 20289.0>, <H7 153.0>, <C5 0.37>, <G11 1.0>, <F8 29.0>, <J8 11495.0>, <F9 18.0>, <C7 0.12>, <B7 15405.0>, <E8 0.03>, <K10 0.19>, <J7 15713.0>, <G5 0.91>, <C11 1.0>, <E6 0.16>, <C9 0.05>, <J11 152001.0>, <K6 0.14>, <H10 27.0>, <B11 131875.0>, <F7 57.0>, <G10 0.01>, <G9 0.0>, <K5 0.44>, <B5 48827.0>, <F11 3784.0>, <J10 29328.0>, <I11 1.0>, <H9 41.0>, <C6 0.15>, <J5 67118.0>, <D11 1537.0>, <D8 45.0>, <D10 84.0>, <F5 3448.0>, <D9 28.0>, <H5 13803.0>, <C8 0.09>, <G7 0.02>, <E9 0.02>, <F6 205.0>, <B10 29190.0>, <E10 0.05>, <D6 242.0>, <E11 1.0>, <D5 1040.0>, <K8 0.08>, <I6 0.05>, <D7 98.0>, <E7 0.06>, <J9 6888.0>, <H6 723.0>, <I10 0.0>, <I9 0.0>, <E5 0.68>, <I8 0.0>, <J6 21459.0>, <H8 58.0>}

# %%
time = tab.excel_ref('A5').expand(DOWN).is_not_blank() 
time
# Out:
# {<A7 '2-3 years'>, <A14 '*Percentages may equal 0% or not sum to 100% due to rounding'>, <A6 '1-2 years'>, <A8 '3-4 years'>, <A10 '5 years +'>, <A5 'Less than 12 months'>, <A11 'Total'>, <A9 '4-5 years'>}

# %%
clients = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
clients
# Out:
# {<H3 'Alcohol only'>, <B3 'Opiate'>, <D3 'Non-opiate only'>, <F3 'Non-opiate and Alcohol'>, <J3 'Total'>}

# %%
MeasureType = tab.excel_ref('B4').expand(RIGHT).is_not_blank()
MeasureType
# Out:
# {<F4 'n'>, <I4 '%'>, <C4 '%'>, <E4 '%'>, <H4 'n'>, <B4 'n'>, <K4 '%'>, <G4 '%'>, <J4 'n'>, <D4 'n'>}

# %%
Dimensions = [
            HDim(clients,'Clients in treatment',CLOSEST,LEFT),
            HDim(time,'Length of time in prescribing',DIRECTLY,LEFT),
            HDim(MeasureType,'Measure Type',DIRECTLY,ABOVE),
            HDimConst('Unit','People')            
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# if is_interactive():
#     savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#           OBS    Clients in treatment Length of time in prescribing  \
# 0    48827.00                  Opiate           Less than 12 months
# 1        0.37                  Opiate           Less than 12 months
# 2     1040.00         Non-opiate only           Less than 12 months
# 3        0.68         Non-opiate only           Less than 12 months
# 4     3448.00  Non-opiate and Alcohol           Less than 12 months
# 5        0.91  Non-opiate and Alcohol           Less than 12 months
# 6    13803.00            Alcohol only           Less than 12 months
# 7        0.93            Alcohol only           Less than 12 months
# 8    67118.00                   Total           Less than 12 months
# 9        0.44                   Total           Less than 12 months
# 10   20289.00                  Opiate                     1-2 years
# 11       0.15                  Opiate                     1-2 years
# 12     242.00         Non-opiate only                     1-2 years
# 13       0.16         Non-opiate only                     1-2 years
# 14     205.00  Non-opiate and Alcohol                     1-2 years
# 15       0.05  Non-opiate and Alcohol                     1-2 years
# 16     723.00            Alcohol only                     1-2 years
# 17       0.05            Alcohol only                     1-2 years
# 18   21459.00                   Total                     1-2 years
# 19       0.14                   Total                     1-2 years
# 20   15405.00                  Opiate                     2-3 years
# 21       0.12                  Opiate                     2-3 years
# 22      98.00         Non-opiate only                     2-3 years
# 23       0.06         Non-opiate only                     2-3 years
# 24      57.00  Non-opiate and Alcohol                     2-3 years
# 25       0.02  Non-opiate and Alcohol                     2-3 years
# 26     153.00            Alcohol only                     2-3 years
# 27       0.01            Alcohol only                     2-3 years
# 28   15713.00                   Total                     2-3 years
# 29       0.10                   Total                     2-3 years
# ..        ...                     ...                           ...
# 40    6801.00                  Opiate                     4-5 years
# 41       0.05                  Opiate                     4-5 years
# 42      28.00         Non-opiate only                     4-5 years
# 43       0.02         Non-opiate only                     4-5 years
# 44      18.00  Non-opiate and Alcohol                     4-5 years
# 45       0.00  Non-opiate and Alcohol                     4-5 years
# 46      41.00            Alcohol only                     4-5 years
# 47       0.00            Alcohol only                     4-5 years
# 48    6888.00                   Total                     4-5 years
# 49       0.05                   Total                     4-5 years
# 50   29190.00                  Opiate                     5 years +
# 51       0.22                  Opiate                     5 years +
# 52      84.00         Non-opiate only                     5 years +
# 53       0.05         Non-opiate only                     5 years +
# 54      27.00  Non-opiate and Alcohol                     5 years +
# 55       0.01  Non-opiate and Alcohol                     5 years +
# 56      27.00            Alcohol only                     5 years +
# 57       0.00            Alcohol only                     5 years +
# 58   29328.00                   Total                     5 years +
# 59       0.19                   Total                     5 years +
# 60  131875.00                  Opiate                         Total
# 61       1.00                  Opiate                         Total
# 62    1537.00         Non-opiate only                         Total
# 63       1.00         Non-opiate only                         Total
# 64    3784.00  Non-opiate and Alcohol                         Total
# 65       1.00  Non-opiate and Alcohol                         Total
# 66   14805.00            Alcohol only                         Total
# 67       1.00            Alcohol only                         Total
# 68  152001.00                   Total                         Total
# 69       1.00                   Total                         Total
#
#    Measure Type    Unit
# 0             n  People
# 1             %  People
# 2             n  People
# 3             %  People
# 4             n  People
# 5             %  People
# 6             n  People
# 7             %  People
# 8             n  People
# 9             %  People
# 10            n  People
# 11            %  People
# 12            n  People
# 13            %  People
# 14            n  People
# 15            %  People
# 16            n  People
# 17            %  People
# 18            n  People
# 19            %  People
# 20            n  People
# 21            %  People
# 22            n  People
# 23            %  People
# 24            n  People
# 25            %  People
# 26            n  People
# 27            %  People
# 28            n  People
# 29            %  People
# ..          ...     ...
# 40            n  People
# 41            %  People
# 42            n  People
# 43            %  People
# 44            n  People
# 45            %  People
# 46            n  People
# 47            %  People
# 48            n  People
# 49            %  People
# 50            n  People
# 51            %  People
# 52            n  People
# 53            %  People
# 54            n  People
# 55            %  People
# 56            n  People
# 57            %  People
# 58            n  People
# 59            %  People
# 60            n  People
# 61            %  People
# 62            n  People
# 63            %  People
# 64            n  People
# 65            %  People
# 66            n  People
# 67            %  People
# 68            n  People
# 69            %  People
#
# [70 rows x 5 columns]

# %%
new_table = new_table[new_table['OBS'] != 0 ]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table.head()
# Out:
#       Value    Clients in treatment Length of time in prescribing  \
# 0  48827.00                  Opiate           Less than 12 months
# 1      0.37                  Opiate           Less than 12 months
# 2   1040.00         Non-opiate only           Less than 12 months
# 3      0.68         Non-opiate only           Less than 12 months
# 4   3448.00  Non-opiate and Alcohol           Less than 12 months
#
#   Measure Type    Unit
# 0            n  People
# 1            %  People
# 2            n  People
# 3            %  People
# 4            n  People

# %%
new_table['Measure Type'].unique()
# Out:
# array(['n', '%'], dtype=object)

# %%
new_table['Measure Type'] = new_table['Measure Type'].map(
    lambda x: {
        'n' : 'Count', 
        '%' : 'Percentage'
        }.get(x, x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table.tail()
# Out:
#        Value    Clients in treatment Length of time in prescribing  \
# 65       1.0  Non-opiate and Alcohol                         Total
# 66   14805.0            Alcohol only                         Total
# 67       1.0            Alcohol only                         Total
# 68  152001.0                   Total                         Total
# 69       1.0                   Total                         Total
#
#    Measure Type    Unit
# 65   Percentage  People
# 66        Count  People
# 67   Percentage  People
# 68        Count  People
# 69   Percentage  People

# %%
new_table.dtypes
# Out:
# Value                            float64
# Clients in treatment              object
# Length of time in prescribing     object
# Measure Type                      object
# Unit                              object
# dtype: object

# %%
new_table['Value'] = new_table['Value'].astype(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table.head(3)
# Out:
#      Value Clients in treatment Length of time in prescribing Measure Type  \
# 0  48827.0               Opiate           Less than 12 months        Count
# 1     0.37               Opiate           Less than 12 months   Percentage
# 2   1040.0      Non-opiate only           Less than 12 months        Count
#
#      Unit
# 0  People
# 1  People
# 2  People

# %%
new_table['Length of time in prescribing'] = new_table['Length of time in prescribing'].map(
    lambda x: {
        'Total' : 'All years' 
        }.get(x, x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table['Clients in treatment'] = new_table['Clients in treatment'].map(
    lambda x: {
        'Total' : 'All' 
        }.get(x, x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table.tail()
# Out:
#        Value    Clients in treatment Length of time in prescribing  \
# 65       1.0  Non-opiate and Alcohol                     All years
# 66   14805.0            Alcohol only                     All years
# 67       1.0            Alcohol only                     All years
# 68  152001.0                     All                     All years
# 69       1.0                     All                     All years
#
#    Measure Type    Unit
# 65   Percentage  People
# 66        Count  People
# 67   Percentage  People
# 68        Count  People
# 69   Percentage  People

# %%
new_table = new_table[['Clients in treatment','Length of time in prescribing','Measure Type','Value','Unit']]

# %%
if is_interactive():
    SubstancetinationFolder = Path('out')
    SubstancetinationFolder.mkdir(exist_ok=True, parents=True)
    new_table.to_csv(SubstancetinationFolder / ('table5.2.4.csv'), index = False)
