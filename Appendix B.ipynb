<L38 1123.0>, <B36 'Prior to 2005-06'>, <I41 29081.0>, <I22 73.0>, <I9 59284.0>, <N5 370.0>, <H24 5050.0>, <H14 3660.0>, <B28 'Prior to 2005-06'>, <J22 73.0>, <E21 16.0>, <B32 2442.0>, <M37 251.0>, <G25 8011.0>, <B16 18244.0>, <G28 '2009-10'>, <O40 8123.0>, <F22 54.0>, <M6 4778.0>, <G14 4875.0>, <P31 63641.0>, <F30 826.0>, <Q24 0.5549283732616775>, <G32 7755.0>, <E41 24374.0>, <G36 '2009-10'>, <M22 204.0>, <B41 7566.0>, <P7 364031.0>, <J14 2657.0>, <P24 63607.0>, <L22 129.0>, <M13 329.0>, <D7 33083.0>, <K13 523.0>, <L29 190.0>, <Q7 0.39576201073467393>, <O16 680.0>, <F17 22979.0>, <M17 7123.0>, <B5 5343.0>, <D5 1986.0>, <G40 18119.0>, <K22 103.0>, <P29 1952.0>, <F33 16116.0>, <K38 1088.0>, <C38 327.0>, <P14 103920.0>, <I12 '2011-12'>, <B30 259.0>, <D23 4784.0>, <B21 9.0>, <E37 124.0>, <Q30 0.0748727221431411>, <L23 2937.0>, <H22 57.0>, <H39 12266.0>, <O6 18314.0>, <N17 6355.0>, <D31 5395.0>, <Q14 0.3463422762872855>, <M40 15656.0>, <E16 7452.0>, <I23 2546.0>, <E13 1376.0>, <I29 183.0>, <B7 36641.0>, <K39 10308.0>, <K41 29481.0>, <C12 '2005-06'>, <K14 2627.0>, <I30 677.0>, <L30 631.0>, <C16 11868.0>, <L21 33.0>, <N14 2628.0>, <M32 4937.0>, <I31 4394.0>, <O13 20.0>, <K5 1100.0>, <G12 '2009-10'>, <G41 33195.0>, <C22 53.0>, <O39 4722.0>, <O25 8555.0>, <J13 566.0>, <M30 712.0>, <K32 6042.0>, <Q31 0.40806499185678197>, <B8 25764.0>, <M31 3755.0>, <J5 1065.0>, <F39 15637.0>, <E15 11458.0>, <Q6 0.1522792972126159>, <K17 8715.0>, <H16 4289.0>, <P37 2560.0>, <B25 4047.0>, <D6 11419.0>, <G20 '2009-10'>, <B40 3490.0>, <P23 46610.0>, <J15 3716.0>, <M23 3370.0>, <B24 1588.0>, <C9 87005.0>, <J39 10085.0>, <F14 6497.0>, <Q15 0.3970338276953841>, <O22 3044.0>, <M21 18.0>, <D8 26371.0>, <J9 57188.0>, <K37 337.0>, <P17 300050.0>, <C15 21008.0>, <L17 7692.0>, <L16 2120.0>, <L37 330.0>, <P12 'Total'>, <F25 8419.0>, <F32 8463.0>, <N41 22757.0>, <H20 ...

# %%
clients = tab.excel_ref('A').expand(DOWN).by_index([3,11,19,27,35])
clients
# Out:
# {<A3 'All substance groups'>, <A35 'Alcohol only clients'>, <A27 'Non-opiate and alcohol clients'>, <A11 'Opiate clients'>, <A19 'Non-opiate only clients'>}

# %%
treatmentstatus = tab.excel_ref('A5').expand(DOWN).is_not_blank() - clients
treatmentstatus
# Out:
# {<A24 'Subtotal treatment complete'>, <A38 'Retained at 31st March 2018'>, <A5 'Three journeys since first presentation'>, <A28 'Category'>, <A14 'Retained at 31st March 2018'>, <A17 'Total clients in treatment since 1st April 2005'>, <A22 'Retained at 31st March 2018'>, <A41 'Total clients in treatment since 1st April 2005'>, <A31 'Subtotal exited (treatment incomplete)'>, <A7 'Subtotal exited (treatment incomplete)'>, <A37 'Three journeys since first presentation'>, <A32 'Subtotal treatment complete'>, <A29 'Three journeys since first presentation'>, <A36 'Category'>, <A9 'Total clients in treatment since 1st April 2005'>, <A12 'Category'>, <A30 'Retained at 31st March 2018'>, <A33 'Total clients in treatment since 1st April 2005'>, <A39 'Subtotal exited (treatment incomplete)'>, <A15 'Subtotal exited (treatment incomplete)'>, <A8 'Subtotal treatment complete'>, <A21 'Three journeys since first presentation'>, <A13 'Three journeys since first presentation'>, <A20 'Category'>, <A6 'Retained at 31st March 2018'>, <A25 'Total clients in treatment since 1st April 2005'>, <A23 'Subtotal exited (treatment incomplete)'>, <A40 'Subtotal treatment complete'>, <A16 'Subtotal treatment complete'>}

# %%
period = tab.excel_ref('B4').expand(RIGHT).is_not_blank() 
period
# Out:
# {<G4 '2009-10'>, <C4 '2005-06'>, <J4 '2012-13'>, <F4 '2008-09'>, <K4 '2013-14'>, <B4 'Prior to 2005-06'>, <O4 '2017-18'>, <H4 '2010-11'>, <I4 '2011-12'>, <L4 '2014-15'>, <P4 'Total'>, <N4 '2016-17'>, <M4 '2015-16'>, <Q4 '%'>, <D4 '2006-07'>, <E4 '2007-08'>}

# %%
Dimensions = [
            HDim(clients,'Clients in treatment',CLOSEST,ABOVE),
            HDimConst('Measure Type','Count'),
            HDim(treatmentstatus, 'Treatment Status',DIRECTLY,LEFT),
            HDim(period, 'Period',DIRECTLY,ABOVE),
            HDimConst('Unit','People')            
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# if is_interactive():
#     savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#            OBS DATAMARKER  Clients in treatment Measure Type  \
# 0         5343        NaN  All substance groups        Count
# 1         2896        NaN  All substance groups        Count
# 2         1986        NaN  All substance groups        Count
# 3         1649        NaN  All substance groups        Count
# 4         1661        NaN  All substance groups        Count
# 5         1432        NaN  All substance groups        Count
# 6         1217        NaN  All substance groups        Count
# 7         1053        NaN  All substance groups        Count
# 8         1065        NaN  All substance groups        Count
# 9         1100        NaN  All substance groups        Count
# 10         947        NaN  All substance groups        Count
# 11         765        NaN  All substance groups        Count
# 12         370        NaN  All substance groups        Count
# 13          46        NaN  All substance groups        Count
# 14       21530        NaN  All substance groups        Count
# 15   0.0234067        NaN  All substance groups        Count
# 16       34483        NaN  All substance groups        Count
# 17       18577        NaN  All substance groups        Count
# 18       11419        NaN  All substance groups        Count
# 19        9149        NaN  All substance groups        Count
# 20        8273        NaN  All substance groups        Count
# 21        6522        NaN  All substance groups        Count
# 22        5197        NaN  All substance groups        Count
# 23        4495        NaN  All substance groups        Count
# 24        4266        NaN  All substance groups        Count
# 25        4525        NaN  All substance groups        Count
# 26        4274        NaN  All substance groups        Count
# 27        4778        NaN  All substance groups        Count
# 28        5798        NaN  All substance groups        Count
# 29       18314        NaN  All substance groups        Count
# ..         ...        ...                   ...          ...
# 438       8483        NaN  Alcohol only clients        Count
# 439      12955        NaN  Alcohol only clients        Count
# 440      18394        NaN  Alcohol only clients        Count
# 441      18119        NaN  Alcohol only clients        Count
# 442      18499        NaN  Alcohol only clients        Count
# 443      17658        NaN  Alcohol only clients        Count
# 444      17664        NaN  Alcohol only clients        Count
# 445      18085        NaN  Alcohol only clients        Count
# 446      16658        NaN  Alcohol only clients        Count
# 447      15656        NaN  Alcohol only clients        Count
# 448      13450        NaN  Alcohol only clients        Count
# 449       8123        NaN  Alcohol only clients        Count
# 457  Total clients in treatment since 1st April 2005           2009-10  People
# 458  Total clients in treatment since 1st April 2005           2010-11  People
# 459  Total clients in treatment since 1st April 2005           2011-12  People
# 460  Total clients in treatment since 1st April 2005           2012-13  People
# 461  Total clients in treatment since 1st April 2005           2013-14  People
# 462  Total clients in treatment since 1st April 2005           2014-15  People
# 463  Total clients in treatment since 1st April 2005           2015-16  People
# 464  Total clients in treatment since 1st April 2005           2016-17  People
# 465  Total clients in treatment since 1st April 2005           2017-18  People
# 466  Total clients in treatment since 1st April 2005             Total  People
# 467  Total clients in treatment since 1st April 2005                 %  People
#
# [468 rows x 7 columns]

# %%
new_table = new_table[new_table['OBS'] != 0 ]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table.head()
# Out:
#   Value DATAMARKER  Clients in treatment Measure Type  \
# 0  5343        NaN  All substance groups        Count
# 1  2896        NaN  All substance groups        Count
# 2  1986        NaN  All substance groups        Count
# 3  1649        NaN  All substance groups        Count
# 4  1661        NaN  All substance groups        Count
#
#                           Treatment Status            Period    Unit
# 0  Three journeys since first presentation  Prior to 2005-06  People
# 1  Three journeys since first presentation           2005-06  People
# 2  Three journeys since first presentation           2006-07  People
# 3  Three journeys since first presentation           2007-08  People
# 4  Three journeys since first presentation           2008-09  People

# %%
new_table['Measure Type'].unique()
# Out:
# array(['Count'], dtype=object)

# %%
new_table.tail()
# Out:
#       Value DATAMARKER  Clients in treatment Measure Type  \
# 463   25572        NaN  Alcohol only clients        Count
# 464   22757        NaN  Alcohol only clients        Count
# 465   21579        NaN  Alcohol only clients        Count
# 466  349193        NaN  Alcohol only clients        Count
# 467       1        NaN  Alcohol only clients        Count
#
#                                     Treatment Status   Period    Unit
# 463  Total clients in treatment since 1st April 2005  2015-16  People
# 464  Total clients in treatment since 1st April 2005  2016-17  People
# 465  Total clients in treatment since 1st April 2005  2017-18  People
# 466  Total clients in treatment since 1st April 2005    Total  People
# 467  Total clients in treatment since 1st April 2005        %  People

# %%
new_table.dtypes
# Out:
# Value                   object
# DATAMARKER              object
# Clients in treatment    object
# Measure Type            object
# Treatment Status        object
# Period                  object
# Unit                    object
# dtype: object

# %%
new_table['Value'] = new_table['Value'].astype(str)

# %%
new_table.head(3)
# Out:
#     Value DATAMARKER  Clients in treatment Measure Type  \
# 0  5343.0        NaN  All substance groups        Count
# 1  2896.0        NaN  All substance groups        Count
# 2  1986.0        NaN  All substance groups        Count
#
#                           Treatment Status            Period    Unit
# 0  Three journeys since first presentation  Prior to 2005-06  People
# 1  Three journeys since first presentation           2005-06  People
# 2  Three journeys since first presentation           2006-07  People

# %%
def user_perc(x,y):
    
    if str(x) == '%':
        return 'Percentage'
    else:
        return y
    
new_table['Measure Type'] = new_table.apply(lambda row: user_perc(row['Period'],row['Measure Type']), axis = 1)

# %%
new_table['Period'] = new_table['Period'].map(
    lambda x: {
        'Total' : 'All years',
        '%'     : 'All years'
        }.get(x, x))

# %%
new_table.tail()
# Out:
#         Value DATAMARKER  Clients in treatment Measure Type  \
# 463   25572.0        NaN  Alcohol only clients        Count
# 464   22757.0        NaN  Alcohol only clients        Count
# 465   21579.0        NaN  Alcohol only clients        Count
# 466  349193.0        NaN  Alcohol only clients        Count
# 467       1.0        NaN  Alcohol only clients   Percentage
#
#                                     Treatment Status     Period    Unit
# 463  Total clients in treatment since 1st April 2005    2015-16  People
# 464  Total clients in treatment since 1st April 2005    2016-17  People
# 465  Total clients in treatment since 1st April 2005    2017-18  People
# 466  Total clients in treatment since 1st April 2005  All years  People
# 467  Total clients in treatment since 1st April 2005  All years  People

# %%
new_table = new_table[['Period','Treatment Status','Clients in treatment','Measure Type','Value','Unit']]

# %%
if is_interactive():
    SubstancetinationFolder = Path('out')
    SubstancetinationFolder.mkdir(exist_ok=True, parents=True)
    new_table.to_csv(SubstancetinationFolder / ('Appendix B.csv'), index = False)
