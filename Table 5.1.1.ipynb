# %% [markdown]
# Table 5.1.1: Waiting times, first and subsequent interventions

# %%
from gssutils import *

if is_interactive():
    import requests
    from cachecontrol import CacheControl
    from cachecontrol.caches.file_cache import FileCache
    from cachecontrol.heuristics import LastModified
    from pathlib import Path

    session = CacheControl(requests.Session(),
                           cache=FileCache('.cache'),
                           heuristic=LastModified())

    sourceFolder = Path('in')
    sourceFolder.mkdir(exist_ok=True)

    inputURL = 'https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/752515/AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx'
    inputFile = sourceFolder / 'AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx'
    response = session.get(inputURL)
    with open(inputFile, 'wb') as f:
      f.write(response.content)

# %%
tab = loadxlstabs(inputFile, sheetids='Table 5.1.1')[0]
# Out:
# Loading in\AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx which has size 272149 bytes
# Table names: ['Table 5.1.1']

# %% [markdown]
# https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/752515/AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx

# %%
observations = tab.excel_ref('C6').expand(DOWN).expand(RIGHT).is_not_blank()
observations
# Out:
# {<H8 4878.0>, <G6 1.71>, <D7 279.0>, <G9 2.61>, <I6 0.970586141855582>, <E10 0.0169169835443288>, <H10 76200.0>, <E6 0.0123562475772064>, <J9 1191.0>, <C6 0.987643752422794>, <K10 0.0432424288081965>, <G10 2.17>, <C8 0.981071428571429>, <H7 1461.0>, <H6 54545.0>, <C7 0.983943370165746>, <K8 0.101822868716627>, <J6 1653.0>, <J10 3444.0>, <K6 0.029413858144418>, <D10 2567.0>, <D9 1152.0>, <E9 0.0217963029534747>, <K7 0.0311671087533156>, <D8 371.0>, <K9 0.072151208578179>, <E7 0.0160566298342541>, <C10 0.983083016455671>, <I10 0.956757571191803>, <G8 2.45>, <C9 0.978203697046525>, <I9 0.927848791421821>, <E8 0.0189285714285714>, <G7 2.13>, <I8 0.898177131283373>, <I7 0.968832891246684>, <H9 15316.0>, <J7 47.0>, <J8 553.0>, <D6 765.0>}

# %%
Source = tab.excel_ref('A6').expand(DOWN).is_not_blank()
Source
# Out:
# {<A6 'Opiate'>, <A9 'Alcohol only'>, <A7 'Non-opiate only'>, <A10 'Total'>, <A8 'Non-opiate and Alcohol'>}

# %%
intervention = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
intervention
# Out:
# {<B3 'First intervention'>, <H3 'Subsequent intervention'>}

# %%
Waitingtimes = tab.excel_ref('B4').expand(RIGHT).is_not_blank()
Waitingtimes
# Out:
# {<F4 'Average waiting time'>, <J4 'Over 3 weeks'>, <D4 'Over 3 weeks'>, <H4 '3 weeks or under'>, <B4 '3 weeks or under'>}

# %%
MeasureType = tab.excel_ref('B5').expand(RIGHT).is_not_blank()
MeasureType
# Out:
# {<B5 'n'>, <I5 '%'>, <C5 '%'>, <H5 'n'>, <K5 '%'>, <E5 '%'>, <G5 'days'>, <D5 'n'>, <J5 'n'>}

# %%
Dimensions = [
            HDim(Source,'Substance',DIRECTLY,LEFT),
            HDim(intervention,'Intervention',CLOSEST,LEFT),
            HDim(Waitingtimes,'Waiting time',CLOSEST,LEFT),
            HDim(MeasureType,'Measure Type',DIRECTLY,ABOVE),
            HDimConst('Unit','People')            
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# if is_interactive():
#     savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#              OBS               Substance             Intervention  \
# 0       0.987644                  Opiate       First intervention
# 1     765.000000                  Opiate       First intervention
# 2       0.012356                  Opiate       First intervention
# 3       1.710000                  Opiate       First intervention
# 4   54545.000000                  Opiate  Subsequent intervention
# 5       0.970586                  Opiate  Subsequent intervention
# 6    1653.000000                  Opiate  Subsequent intervention
# 7       0.029414                  Opiate  Subsequent intervention
# 8       0.983943         Non-opiate only       First intervention
# 9     279.000000         Non-opiate only       First intervention
# 10      0.016057         Non-opiate only       First intervention
# 11      2.130000         Non-opiate only       First intervention
# 12   1461.000000         Non-opiate only  Subsequent intervention
# 13      0.968833         Non-opiate only  Subsequent intervention
# 14     47.000000         Non-opiate only  Subsequent intervention
# 15      0.031167         Non-opiate only  Subsequent intervention
# 16      0.981071  Non-opiate and Alcohol       First intervention
# 17    371.000000  Non-opiate and Alcohol       First intervention
# 18      0.018929  Non-opiate and Alcohol       First intervention
# 19      2.450000  Non-opiate and Alcohol       First intervention
# 20   4878.000000  Non-opiate and Alcohol  Subsequent intervention
# 21      0.898177  Non-opiate and Alcohol  Subsequent intervention
# 22    553.000000  Non-opiate and Alcohol  Subsequent intervention
# 23      0.101823  Non-opiate and Alcohol  Subsequent intervention
# 24      0.978204            Alcohol only       First intervention
# 25   1152.000000            Alcohol only       First intervention
# 26      0.021796            Alcohol only       First intervention
# 27      2.610000            Alcohol only       First intervention
# 28  15316.000000            Alcohol only  Subsequent intervention
# 29      0.927849            Alcohol only  Subsequent intervention
# 30   1191.000000            Alcohol only  Subsequent intervention
# 31      0.072151            Alcohol only  Subsequent intervention
# 32      0.983083                   Total       First intervention
# 33   2567.000000                   Total       First intervention
# 34      0.016917                   Total       First intervention
# 35      2.170000                   Total       First intervention
# 36  76200.000000                   Total  Subsequent intervention
# 37      0.956758                   Total  Subsequent intervention
# 38   3444.000000                   Total  Subsequent intervention
# 39      0.043242                   Total  Subsequent intervention
#
#             Waiting time Measure Type    Unit
# 0       3 weeks or under            %  People
# 1           Over 3 weeks            n  People
# 2           Over 3 weeks            %  People
# 3   Average waiting time         days  People
# 4       3 weeks or under            n  People
# 5       3 weeks or under            %  People
# 6           Over 3 weeks            n  People
# 7           Over 3 weeks            %  People
# 8       3 weeks or under            %  People
# 9           Over 3 weeks            n  People
# 10          Over 3 weeks            %  People
# 11  Average waiting time         days  People
# 12      3 weeks or under            n  People
# 13      3 weeks or under            %  People
# 14          Over 3 weeks            n  People
# 15          Over 3 weeks            %  People
# 16      3 weeks or under            %  People
# 17          Over 3 weeks            n  People
# 18          Over 3 weeks            %  People
# 19  Average waiting time         days  People
# 20      3 weeks or under            n  People
# 21      3 weeks or under            %  People
# 22          Over 3 weeks            n  People
# 23          Over 3 weeks            %  People
# 24      3 weeks or under            %  People
# 25          Over 3 weeks            n  People
# 26          Over 3 weeks            %  People
# 27  Average waiting time         days  People
# 28      3 weeks or under            n  People
# 29      3 weeks or under            %  People
# 30          Over 3 weeks            n  People
# 31          Over 3 weeks            %  People
# 32      3 weeks or under            %  People
# 33          Over 3 weeks            n  People
# 34          Over 3 weeks            %  People
# 35  Average waiting time         days  People
# 36      3 weeks or under            n  People
# 37      3 weeks or under            %  People
# 38          Over 3 weeks            n  People
# 39          Over 3 weeks            %  People

# %%
new_table = new_table[new_table['OBS'] != 0 ]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table.head()
# Out:
#           Value Substance             Intervention          Waiting time  \
# 0      0.987644    Opiate       First intervention      3 weeks or under
# 1    765.000000    Opiate       First intervention          Over 3 weeks
# 2      0.012356    Opiate       First intervention          Over 3 weeks
# 3      1.710000    Opiate       First intervention  Average waiting time
# 4  54545.000000    Opiate  Subsequent intervention      3 weeks or under
#
#   Measure Type    Unit
# 0            %  People
# 1            n  People
# 2            %  People
# 3         days  People
# 4            n  People

# %%
new_table['Measure Type'] = new_table['Measure Type'].map(
    lambda x: {
        'n' : 'Count', 
        '%' : 'Percentage',
        }.get(x, x))

# %%
new_table.tail()
# Out:
#            Value Substance             Intervention          Waiting time  \
# 35      2.170000     Total       First intervention  Average waiting time
# 36  76200.000000     Total  Subsequent intervention      3 weeks or under
# 37      0.956758     Total  Subsequent intervention      3 weeks or under
# 38   3444.000000     Total  Subsequent intervention          Over 3 weeks
# 39      0.043242     Total  Subsequent intervention          Over 3 weeks
#
#    Measure Type    Unit
# 35         days  People
# 36        Count  People
# 37   Percentage  People
# 38        Count  People
# 39   Percentage  People

# %%
new_table.dtypes
# Out:
# Value           float64
# Substance        object
# Intervention     object
# Waiting time     object
# Measure Type     object
# Unit             object
# dtype: object

# %%
new_table['Value'] = new_table['Value'].astype(str)

# %%
new_table.head(3)
# Out:
#                 Value Substance        Intervention      Waiting time  \
# 0   0.987643752422794    Opiate  First intervention  3 weeks or under
# 1               765.0    Opiate  First intervention      Over 3 weeks
# 2  0.0123562475772064    Opiate  First intervention      Over 3 weeks
#
#   Measure Type    Unit
# 0   Percentage  People
# 1        Count  People
# 2   Percentage  People

# %%
new_table['Substance'] = new_table['Substance'].map(
    lambda x: {
        'Total' : 'All' 
        }.get(x, x))

# %%
new_table.head(3)
# Out:
#                 Value Substance        Intervention      Waiting time  \
# 0   0.987643752422794    Opiate  First intervention  3 weeks or under
# 1               765.0    Opiate  First intervention      Over 3 weeks
# 2  0.0123562475772064    Opiate  First intervention      Over 3 weeks
#
#   Measure Type    Unit
# 0   Percentage  People
# 1        Count  People
# 2   Percentage  People

# %%
new_table = new_table[['Substance','Intervention','Waiting time','Measure Type','Value','Unit']]

# %%
if is_interactive():
    SubstancetinationFolder = Path('out')
    SubstancetinationFolder.mkdir(exist_ok=True, parents=True)
    new_table.to_csv(SubstancetinationFolder / ('table5.1.1.csv'), index = False)
