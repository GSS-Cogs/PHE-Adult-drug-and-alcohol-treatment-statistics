>, <I13 0.0073109344412928>, <H8 1174.0>, <G17 0.00866228070175439>, <I22 0.0>, <H12 277.0>, <C5 0.85157055517637>, <K16 0.00636138585710007>, <F5 22782.0>, <E5 0.794865277071683>, <I18 0.00139826614997403>, <J16 1678.0>, <C9 0.0115667794542629>, <B19 415.0>, <I23 1.0>, <D21 14.0>, <H22 0.0>, <H15 390.0>, <H9 1260.0>, <F14 163.0>, <B11 1232.0>, <D8 179.0>, <G14 0.00595760233918129>, <F17 237.0>, <K14 0.00768825418247851>, <E20 0.00432130147432639>, <C15 0.00565632215622776>, <H16 639.0>, <E22 0.0>, <C22 0.0>, <G15 0.0107090643274854>, <J20 593.0>, <F11 416.0>, <K5 0.844551689103378>, <J18 1252.0>, <K11 0.00926154091114152>, <B14 1208.0>, <H21 26.0>, <I11 0.00535336183132915>, <C23 1.0>, <I6 0.0407095201949583>, <K18 0.0047463975524966>, <D22 0.0>, <D17 261.0>, <K6 0.039226018750545>, <B7 1782.0>, <I21 0.000346237332374522>, <E11 0.0166497203863752>}

# %%
Ethnicity = tab.excel_ref('A5').expand(DOWN).is_not_blank()
Ethnicity
# Out:
# {<A12 'Pakistani'>, <A19 'White and Asian'>, <A23 'Total'>, <A6 'Other white'>, <A21 'Chinese'>, <A25 'Total'>, <A5 'White British'>, <A7 'Not stated'>, <A14 'Other'>, <A8 'White Irish'>, <A9 'Indian'>, <A16 'African'>, <A15 'Other black'>, <A18 'Bangladeshi'>, <A11 'White and black Caribbean'>, <A13 'Other Asian'>, <A17 'Other mixed'>, <A22 'Unknown'>, <A28 '*Percentages may equal 0% or not sum to 100% due to rounding'>, <A24 'Inconsistent/missing'>, <A10 'Caribbean'>, <A20 'White and black African'>}

# %%
Clients = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
Clients
# Out:
# {<D3 'Non-opiate only'>, <J3 'Total'>, <H3 'Alcohol only'>, <B3 'Opiate'>, <F3 'Non-opiate and Alcohol'>}

# %%
MeasureType = tab.excel_ref('B4').expand(RIGHT).is_not_blank()
MeasureType
# Out:
# {<D4 'n'>, <B4 'n'>, <K4 '%'>, <H4 'n'>, <J4 'n'>, <G4 '%'>, <I4 '%'>, <F4 'n'>, <C4 '%'>, <E4 '%'>}

# %%
Dimensions = [
            HDim(Ethnicity,'Ethnicity',DIRECTLY,LEFT),
            HDim(Clients,'Clients',CLOSEST,LEFT),
            HDim(MeasureType,'Measure Type',DIRECTLY,ABOVE),
            HDimConst('Unit','People')            
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# if is_interactive():
#     savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#                OBS             Ethnicity                 Clients Measure Type  \
# 0    117280.000000         White British                  Opiate            n
# 1         0.851571         White British                  Opiate            %
# 2     18762.000000         White British         Non-opiate only            n
# 3         0.794865         White British         Non-opiate only            %
# 4     22782.000000         White British  Non-opiate and Alcohol            n
# 5         0.832675         White British  Non-opiate and Alcohol            %
# 6     63951.000000         White British            Alcohol only            n
# 7         0.851624         White British            Alcohol only            %
# 8    222775.000000         White British                   Total            n
# 9         0.844552         White British                   Total            %
# 10     5579.000000           Other white                  Opiate            n
# 11        0.040509           Other white                  Opiate            %
# 12      851.000000           Other white         Non-opiate only            n
# 13        0.036053           Other white         Non-opiate only            %
# 14      860.000000           Other white  Non-opiate and Alcohol            n
# 15        0.031433           Other white  Non-opiate and Alcohol            %
# 16     3057.000000           Other white            Alcohol only            n
# 17        0.040710           Other white            Alcohol only            %
# 18    10347.000000           Other white                   Total            n
# 19        0.039226           Other white                   Total            %
# 20     1782.000000            Not stated                  Opiate            n
# 21        0.012939            Not stated                  Opiate            %
# 22      645.000000            Not stated         Non-opiate only            n
# 23        0.027326            Not stated         Non-opiate only            %
# 24      549.000000            Not stated  Non-opiate and Alcohol            n
# 25        0.020066            Not stated  Non-opiate and Alcohol            %
# 26     1716.000000            Not stated            Alcohol only            n
# 27        0.022852            Not stated            Alcohol only            %
# 28     4692.000000            Not stated                   Total            n
# 29        0.017788            Not stated                   Total            %
# ..             ...                   ...                     ...          ...
# 170       0.000000               Unknown                  Opiate            n
# 171       0.000000               Unknown                  Opiate            %
# 172       0.000000               Unknown         Non-opiate only            n
# 173       0.000000               Unknown         Non-opiate only            %
# 174       0.000000               Unknown  Non-opiate and Alcohol            n
# 175       0.000000               Unknown  Non-opiate and Alcohol            %
# 176       0.000000               Unknown            Alcohol only            n
# 177       0.000000               Unknown            Alcohol only            %
# 178       0.000000               Unknown                   Total            n
# 179       0.000000               Unknown                   Total            %
# 180  137722.000000                 Total                  Opiate            n
# 181       1.000000                 Total                  Opiate            %
# 182   23604.000000                 Total         Non-opiate only            n
# 183       1.000000                 Total         Non-opiate only            %
# 184   27360.000000                 Total  Non-opiate and Alcohol            n
# 185       1.000000                 Total  Non-opiate and Alcohol            %
# 186   75093.000000                 Total            Alcohol only            n
# 187       1.000000                 Total            Alcohol only            %
# 188  263779.000000                 Total                   Total            n
# 189       1.000000                 Total                   Total            %
# 190    3467.000000  Inconsistent/missing                  Opiate            n
# 191     126.000000  Inconsistent/missing         Non-opiate only            n
# 192     324.000000  Inconsistent/missing  Non-opiate and Alcohol            n
# 193     694.000000  Inconsistent/missing            Alcohol only            n
# 194    4611.000000  Inconsistent/missing                   Total            n
# 195  141189.000000                 Total                  Opiate            n
# 196   23730.000000                 Total         Non-opiate only            n
# 197   27684.000000                 Total  Non-opiate and Alcohol            n
# 198   75787.000000                 Total            Alcohol only            n
# 199  268390.000000                 Total                   Total            n
#
#        Unit
# 0    People
# 1    People
# 2    People
# 3    People
# 4    People
# 5    People
# 6    People
# 7    People
# 8    People
# 9    People
# 10   People
# 11   People
# 12   People
# 13   People
# 14   People
# 15   People
# 16   People
# 17   People
# 18   People
# 19   People
# 20   People
# 21   People
# 22   People
# 23   People
# 24   People
# 25   People
# 26   People
# 27   People
# 28   People
# 29   People
# ..      ...
# 170  People
# 171  People
# 172  People
# 173  People
# 174  People
# 175  People
# 176  People
# 177  People
# 178  People
# 179  People
# 180  People
# 181  People
# 182  People
# 183  People
# 184  People
# 185  People
# 186  People
# 187  People
# 188  People
# 189  People
# 190  People
# 191  People
# 192  People
# 193  People
# 194  People
# 195  People
# 196  People
# 197  People
# 198  People
# 199  People
#
# [200 rows x 5 columns]

# %%
new_table = new_table[new_table['OBS'] != 0 ]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table['Measure Type'] = new_table['Measure Type'].map(
    lambda x: {
        'n' : 'Count', 
        '%' : 'Percentage',
        }.get(x, x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table.head()
# Out:
#            Value      Ethnicity                 Clients Measure Type    Unit
# 0  117280.000000  White British                  Opiate        Count  People
# 1       0.851571  White British                  Opiate   Percentage  People
# 2   18762.000000  White British         Non-opiate only        Count  People
# 3       0.794865  White British         Non-opiate only   Percentage  People
# 4   22782.000000  White British  Non-opiate and Alcohol        Count  People

# %%
new_table.dtypes
# Out:
# Value           float64
# Ethnicity        object
# Clients          object
# Measure Type     object
# Unit             object
# dtype: object

# %%
new_table['Value'] = new_table['Value'].astype(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table.head(3)
# Out:
#             Value      Ethnicity          Clients Measure Type    Unit
# 0        117280.0  White British           Opiate        Count  People
# 1  0.851570555176  White British           Opiate   Percentage  People
# 2         18762.0  White British  Non-opiate only        Count  People

# %%
new_table['Ethnicity'] = new_table['Ethnicity'].map(
    lambda x: {
        'Total' : 'All' 
        }.get(x, x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table['Clients'] = new_table['Clients'].map(
    lambda x: {
        'Total' : 'All Clients',
        }.get(x, x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table.head(3)
# Out:
#             Value      Ethnicity          Clients Measure Type    Unit
# 0        117280.0  White British           Opiate        Count  People
# 1  0.851570555176  White British           Opiate   Percentage  People
# 2         18762.0  White British  Non-opiate only        Count  People

# %%
new_table = new_table[['Ethnicity','Clients','Measure Type','Value','Unit']]

# %%
if is_interactive():
    SubstancetinationFolder = Path('out')
    SubstancetinationFolder.mkdir(exist_ok=True, parents=True)
    new_table.to_csv(SubstancetinationFolder / ('table4.4.1.csv'), index = False)
