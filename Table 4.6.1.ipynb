# %% [markdown]
# Table 4.6.1: Religion, new presentations to treatment

# %%
from gssutils import *

if is_interactive():
    import requests
    from cachecontrol import CacheControl
    from cachecontrol.caches.file_cache import FileCache
    from cachecontrol.heuristics import LastModified
    from pathlib import Path

    session = CacheControl(requests.Session(),
                           cache=FileCache('.cache'),
                           heuristic=LastModified())

    sourceFolder = Path('in')
    sourceFolder.mkdir(exist_ok=True)

    inputURL = 'https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/752515/AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx'
    inputFile = sourceFolder / 'AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx'
    response = session.get(inputURL)
    with open(inputFile, 'wb') as f:
      f.write(response.content)

# %%
tab = loadxlstabs(inputFile, sheetids='Table 4.6.1')[0]
# Out:
# Loading in\AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx which has size 272149 bytes
# Table names: ['Table 4.6.1']

# %% [markdown]
# https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/752515/AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx

# %%
observations = tab.excel_ref('B5').expand(DOWN).expand(RIGHT).is_not_blank()
observations
# Out:
# {<D7 3126.0>, <B12 104.0>, <G12 0.00187404168323017>, <H8 329.0>, <K19 1.0>, <K18 0.0907406500481578>, <F11 377.0>, <I17 0.0471596563559924>, <K7 0.25751342703691>, <J14 9.0>, <F5 1.0>, <E7 0.202042399172699>, <F18 1420.0>, <E5 0.000129265770423992>, <G16 0.579135669260037>, <H14 1.0>, <F14 0.0>, <I7 0.303491276885269>, <E9 6.46328852119959e-05>, <F12 33.0>, <H10 45.0>, <H6 169.0>, <E13 0.00336091003102379>, <H17 2322.0>, <D17 669.0>, <I15 0.0288400999248533>, <F10 23.0>, <E8 0.00258531540847983>, <C9 0.000124390486615584>, <B18 3941.0>, <H20 1419.0>, <H16 24514.0>, <B6 243.0>, <G15 0.0308365040604236>, <G13 0.00459992049520132>, <I19 1.0>, <D20 1244.0>, <C19 1.0>, <H11 508.0>, <H7 14943.0>, <E10 0.00200361944157187>, <J7 31549.0>, <F13 81.0>, <J21 127307.0>, <J8 566.0>, <B13 341.0>, <C11 0.0322917703254055>, <G6 0.00442955306945312>, <F17 836.0>, <E15 0.0274689762150982>, <B21 41178.0>, <D16 9142.0>, <G18 0.0806405815208132>, <H19 49237.0>, <C16 0.537615683152552>, <G9 0.000113578283832131>, <I14 2.03099295245445e-05>, <E6 0.00323164426059979>, <K9 0.000114272654553765>, <H15 1420.0>, <C18 0.098044581550403>, <H5 5.0>, <K5 0.000130597319490017>, <J16 65464.0>, <J13 934.0>, <I12 0.00172634400958629>, <K15 0.0292374749008277>, <I8 0.00668196681357516>, <I5 0.000101549647622723>, <B11 1298.0>, <G8 0.00335055937304787>, <K10 0.00120802520528266>, <G19 1.0>, <K12 0.00210588177677653>, <H12 85.0>, <J10 148.0>, <E18 0.0857032057911065>, <B8 138.0>, <J15 3582.0>, <K16 0.534338932693406>, <J6 540.0>, <F21 18757.0>, <J17 5563.0>, <J9 14.0>, <F7 3958.0>, <D5 2.0>, <H21 50656.0>, <H18 4430.0>, <J11 2754.0>, <B10 49.0>, <J20 4793.0>, <I13 0.00934256758129049>, <F8 59.0>, <E19 1.0>, <G14 0.0>, <K17 0.0454070555201854>, <C6 0.00604537764951736>, <C14 0.000174146681261817>, <C7 0.236889242710717>, <C12 0.00258732212160414>, <K14 7.34609922131348e-05>, <D21 16716.0>, <C13 0.0084834311871828>, <B9 5.0>, <F19 17609.0>, <D12 36.0>, <J12 258.0>, <B16 21610.0>, <D13 52.0>, <D18 1326.0>, <E11 0.0369053774560496>, <C8 0.00343317743059011>, <G17 0.0474757226418309>, <D11 571.0>, <D10 31.0>, <K8 0.00461988017695937>, <D6 50.0>, <B20 982.0>, <D15 425.0>, <K11 0.0224790636172193>, <G5 5.67891419160657e-05>, <C10 0.00121902676883272>, <I10 0.000913946828604505>, <J5 16.0>, <C5 0.000199024778584934>, <D8 40.0>, <B19 40196.0>, <D9 1.0>, <B15 1194.0>, <E17 0.0432394002068252>, <D14 1.0>, <I18 0.0899729877937324>, <I6 0.00343237808964803>, <C17 0.0431883769529306>, <D19 15472.0>, <I16 0.497877612364685>, <K13 0.00762361852522977>, <B17 1736.0>, <F20 1148.0>, <K6 0.00440765953278809>, <B7 9522.0>, <J19 122514.0>, <F15 543.0>, <B14 7.0>, <C15 0.0297044482038014>, <F6 78.0>, <H9 6.0>, <G11 0.0214095065023567>, <F16 10198.0>, <E12 0.00232678386763185>, <E16 0.590873836608066>, <I11 0.0103174441984686>, <B5 8.0>, <G7 0.224771423703788>, <G10 0.00130615026406951>, <J18 11117.0>, <H13 460.0>, <F9 2.0>, <I9 0.000121859577147267>, <E14 6.46328852119959e-05>}

# %%
Religion = tab.excel_ref('A5').expand(DOWN).is_not_blank() - tab.excel_ref('A21')
Religion
# Out:
# {<A16 'None'>, <A12 'Pagan'>, <A8 'Hindu'>, <A7 'Christian'>, <A10 'Jewish'>, <A17 'Decline'>, <A9 'Jain'>, <A6 'Buddhist'>, <A5 "Baha'i">, <A19 'Total'>, <A18 'Unknown'>, <A13 'Sikh'>, <A20 'Inconsistent/missing'>, <A15 'Other'>, <A14 'Zoroastrian'>, <A11 'Muslim'>}

# %%
Clients = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
Clients
# Out:
# {<D3 'Non-opiate only'>, <B3 'Opiate'>, <F3 'Non-opiate and Alcohol'>, <H3 'Alcohol only'>, <J3 'Total'>}

# %%
MeasureType = tab.excel_ref('B4').expand(RIGHT).is_not_blank()
MeasureType
# Out:
# {<F4 'n'>, <H4 'n'>, <I4 '%'>, <C4 '%'>, <E4 '%'>, <B4 'n'>, <K4 '%'>, <G4 '%'>, <J4 'n'>, <D4 'n'>}

# %%
Dimensions = [
            HDim(Religion,'Religion',DIRECTLY,LEFT),
            HDim(Clients,'Clients',CLOSEST,LEFT),
            HDim(MeasureType,'Measure Type',DIRECTLY,ABOVE),
            HDimConst('Unit','People')            
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# if is_interactive():
#     savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#                OBS              Religion                 Clients Measure Type  \
# 0         8.000000                Baha'i                  Opiate            n
# 1         0.000199                Baha'i                  Opiate            %
# 2         2.000000                Baha'i         Non-opiate only            n
# 3         0.000129                Baha'i         Non-opiate only            %
# 4         1.000000                Baha'i  Non-opiate and Alcohol            n
# 5         0.000057                Baha'i  Non-opiate and Alcohol            %
# 6         5.000000                Baha'i            Alcohol only            n
# 7         0.000102                Baha'i            Alcohol only            %
# 8        16.000000                Baha'i                   Total            n
# 9         0.000131                Baha'i                   Total            %
# 10      243.000000              Buddhist                  Opiate            n
# 11        0.006045              Buddhist                  Opiate            %
# 12       50.000000              Buddhist         Non-opiate only            n
# 13        0.003232              Buddhist         Non-opiate only            %
# 14       78.000000              Buddhist  Non-opiate and Alcohol            n
# 15        0.004430              Buddhist  Non-opiate and Alcohol            %
# 16      169.000000              Buddhist            Alcohol only            n
# 17        0.003432              Buddhist            Alcohol only            %
# 18      540.000000              Buddhist                   Total            n
# 19        0.004408              Buddhist                   Total            %
# 20     9522.000000             Christian                  Opiate            n
# 21        0.236889             Christian                  Opiate            %
# 22     3126.000000             Christian         Non-opiate only            n
# 23        0.202042             Christian         Non-opiate only            %
# 24     3958.000000             Christian  Non-opiate and Alcohol            n
# 25        0.224771             Christian  Non-opiate and Alcohol            %
# 26    14943.000000             Christian            Alcohol only            n
# 27        0.303491             Christian            Alcohol only            %
# 28    31549.000000             Christian                   Total            n
# 29        0.257513             Christian                   Total            %
# ..             ...                   ...                     ...          ...
# 130    3941.000000               Unknown                  Opiate            n
# 131       0.098045               Unknown                  Opiate            %
# 132    1326.000000               Unknown         Non-opiate only            n
# 133       0.085703               Unknown         Non-opiate only            %
# 134    1420.000000               Unknown  Non-opiate and Alcohol            n
# 135       0.080641               Unknown  Non-opiate and Alcohol            %
# 136    4430.000000               Unknown            Alcohol only            n
# 137       0.089973               Unknown            Alcohol only            %
# 138   11117.000000               Unknown                   Total            n
# 139       0.090741               Unknown                   Total            %
# 140   40196.000000                 Total                  Opiate            n
# 141       1.000000                 Total                  Opiate            %
# 142   15472.000000                 Total         Non-opiate only            n
# 143       1.000000                 Total         Non-opiate only            %
# 144   17609.000000                 Total  Non-opiate and Alcohol            n
# 145       1.000000                 Total  Non-opiate and Alcohol            %
# 146   49237.000000                 Total            Alcohol only            n
# 147       1.000000                 Total            Alcohol only            %
# 148  122514.000000                 Total                   Total            n
# 149       1.000000                 Total                   Total            %
# 150     982.000000  Inconsistent/missing                  Opiate            n
# 151    1244.000000  Inconsistent/missing         Non-opiate only            n
# 152    1148.000000  Inconsistent/missing  Non-opiate and Alcohol            n
# 153    1419.000000  Inconsistent/missing            Alcohol only            n
# 154    4793.000000  Inconsistent/missing                   Total            n
# 155   41178.000000                  None                  Opiate            n
# 156   16716.000000                  None         Non-opiate only            n
# 157   18757.000000                  None  Non-opiate and Alcohol            n
# 158   50656.000000                  None            Alcohol only            n
# 159  127307.000000                  None                   Total            n
#
#        Unit
# 0    People
# 1    People
# 2    People
# 3    People
# 4    People
# 5    People
# 6    People
# 7    People
# 8    People
# 9    People
# 10   People
# 11   People
# 12   People
# 13   People
# 14   People
# 15   People
# 16   People
# 17   People
# 18   People
# 19   People
# 20   People
# 21   People
# 22   People
# 23   People
# 24   People
# 25   People
# 26   People
# 27   People
# 28   People
# 29   People
# ..      ...
# 130  People
# 131  People
# 132  People
# 133  People
# 134  People
# 135  People
# 136  People
# 137  People
# 138  People
# 139  People
# 140  People
# 141  People
# 142  People
# 143  People
# 144  People
# 145  People
# 146  People
# 147  People
# 148  People
# 149  People
# 150  People
# 151  People
# 152  People
# 153  People
# 154  People
# 155  People
# 156  People
# 157  People
# 158  People
# 159  People
#
# [160 rows x 5 columns]

# %%
new_table = new_table[new_table['OBS'] != 0 ]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table['Measure Type'] = new_table['Measure Type'].map(
    lambda x: {
        'n' : 'Count', 
        '%' : 'Percentage',
        }.get(x, x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table.head()
# Out:
#       Value Religion                 Clients Measure Type    Unit
# 0  8.000000   Baha'i                  Opiate        Count  People
# 1  0.000199   Baha'i                  Opiate   Percentage  People
# 2  2.000000   Baha'i         Non-opiate only        Count  People
# 3  0.000129   Baha'i         Non-opiate only   Percentage  People
# 4  1.000000   Baha'i  Non-opiate and Alcohol        Count  People

# %%
new_table.dtypes
# Out:
# Value           float64
# Religion         object
# Clients          object
# Measure Type     object
# Unit             object
# dtype: object

# %%
new_table['Value'] = new_table['Value'].astype(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_table.head(3)
# Out:
#                   Value Religion          Clients Measure Type    Unit
# 0                   8.0   Baha'i           Opiate        Count  People
# 1  0.000199024778584934   Baha'i           Opiate   Percentage  People
# 2                   2.0   Baha'i  Non-opiate only        Count  People

# %%
new_table['Religion'] = new_table['Religion'].map(
    lambda x: {
        'Total' : 'All' 
        }.get(x, x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table['Religion'].unique()
# Out:
# array(["Baha'i", 'Buddhist', 'Christian', 'Hindu', 'Jain', 'Jewish',
#        'Muslim', 'Pagan', 'Sikh', 'Zoroastrian', 'Other', 'None',
#        'Decline', 'Unknown', 'All', 'Inconsistent/missing', None],
#       dtype=object)

# %%
def user_perc(x):
    
    if x == None :
        return 'All inclusice Inconsistent/missing'
    else:
        return x
    
new_table['Religion'] = new_table.apply(lambda row: user_perc(row['Religion']), axis = 1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table['Clients'] = new_table['Clients'].map(
    lambda x: {
        'Total' : 'All Clients',
        }.get(x, x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_table.head(3)
# Out:
#                   Value Religion          Clients Measure Type    Unit
# 0                   8.0   Baha'i           Opiate        Count  People
# 1  0.000199024778584934   Baha'i           Opiate   Percentage  People
# 2                   2.0   Baha'i  Non-opiate only        Count  People

# %%
new_table = new_table[['Religion','Clients','Measure Type','Value','Unit']]

# %%
if is_interactive():
    SubstancetinationFolder = Path('out')
    SubstancetinationFolder.mkdir(exist_ok=True, parents=True)
    new_table.to_csv(SubstancetinationFolder / ('table4.6.1.csv'), index = False)
