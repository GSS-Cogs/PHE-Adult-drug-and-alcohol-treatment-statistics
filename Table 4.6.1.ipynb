# %% [markdown]
# Table 4.6.1: Religion, new presentations to treatment

# %%
from gssutils import *

if is_interactive():
    scraper = Scraper('https://www.gov.uk/government/collections/alcohol-and-drug-misuse-and-treatment-statistics')
    scraper.select_dataset(title=lambda x: x.startswith('Substance misuse treatment for adults'), latest=True)
    tabs = {tab.name: tab for tab in scraper.distribution(title=lambda x: x.startswith('Data tables')).as_databaker()}

# %%
tab = tabs['Table 4.6.1']

# %% [markdown]
# https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/752515/AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx

# %%
cell = tab.filter('Religion')
cell.assert_one()
observations = tab.filter('n').fill(DOWN).is_not_blank().is_not_whitespace()
Religion = cell.expand(DOWN).is_not_blank().is_not_whitespace()
Clients = cell.expand(RIGHT).is_not_blank().is_not_whitespace()
Dimensions = [
            HDim(Religion,'Treatment group',DIRECTLY,LEFT),
            HDim(Clients,'Clients in treatment',CLOSEST,LEFT),
            HDimConst('Measure Type','Count'),
            HDimConst('Unit','clients in new treatment'),
            HDimConst('Period', '2018-03-31T00:00:00/P1Y'),
            HDimConst('Basis of treatment','religion')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
if is_interactive():
    savepreviewhtml(c1)
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc0" style="background-color:Aqua">OBS</td><td class="xc1" style="background-color:LightGreen">Treatment group</td><td class="xc2" style="background-color:MistyRose">Clients in treatment</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Table 4.6.1</caption>
# <tr><td title="0 0">Table 4.6.1: Religion, new presentations to treatment</td><td title="1 0"></td><td title="2 0"></td><td title="3 0"></td><td title="4 0"></td><td title="5 0"></td><td title="6 0"></td><td title="7 0"></td><td title="8 0"></td><td title="9 0"></td><td title="10 0"></td></tr>
# <tr><td title="0 1">Link back to the index</td><td title="1 1"></td><td title="2 1"></td><td title="3 1"></td><td title="4 1"></td><td title="5 1"></td><td title="6 1"></td><td title="7 1"></td><td title="8 1"></td><td title="9 1"></td><td title="10 1"></td></tr>
# <tr><td style="background-color:MistyRose" title="0 2">Religion</td><td style="background-color:MistyRose" title="1 2">Opiate</td><td title="2 2"></td><td style="background-color:MistyRose" title="3 2">Non-opiate only</td><td title="4 2"></td><td style="background-color:MistyRose" title="5 2">Non-opiate and Alcohol</td><td title="6 2"></td><td style="background-color:MistyRose" title="7 2">Alcohol only</td><td title="8 2"></td><td style="background-color:MistyRose" title="9 2">Total</td><td title="10 2"></td></tr>
# <tr><td title="0 3"></td><td title="1 3">n</td><td title="2 3">%</td><td title="3 3">n</td><td title="4 3">%</td><td title="5 3">n</td><td title="6 3">%</td><td title="7 3">n</td><td title="8 3">%</td><td title="9 3">n</td><td title="10 3">%</td></tr>
# <tr><td style="background-color:LightGreen" title="0 4">Baha'i</td><td style="background-color:Aqua" title="1 4">8.0</td><td title="2 4">0.000199024778584934</td><td style="background-color:Aqua" title="3 4">2.0</td><td title="4 4">0.000129265770423992</td><td style="background-color:Aqua" title="5 4">1.0</td><td title="6 4">5.67891419160657e-05</td><td style="background-color:Aqua" title="7 4">5.0</td><td title="8 4">0.000101549647622723</td><td style="background-color:Aqua" title="9 4">16.0</td><td title="10 4">0.000130597319490017</td></tr>
# <tr><td style="background-color:LightGreen" title="0 5">Buddhist</td><td style="background-color:Aqua" title="1 5">243.0</td><td title="2 5">0.00604537764951736</td><td style="background-color:Aqua" title="3 5">50.0</td><td title="4 5">0.00323164426059979</td><td style="background-color:Aqua" title="5 5">78.0</td><td title="6 5">0.00442955306945312</td><td style="background-color:Aqua" title="7 5">169.0</td><td title="8 5">0.00343237808964803</td><td style="background-color:Aqua" title="9 5">540.0</td><td title="10 5">0.00440765953278809</td></tr>
# <tr><td style="background-color:LightGreen" title="0 6
></tr>
# <tr><td style="background-color:LightGreen" title="0 12">Sikh</td><td style="background-color:Aqua" title="1 12">341.0</td><td title="2 12">0.0084834311871828</td><td style="background-color:Aqua" title="3 12">52.0</td><td title="4 12">0.00336091003102379</td><td style="background-color:Aqua" title="5 12">81.0</td><td title="6 12">0.00459992049520132</td><td style="background-color:Aqua" title="7 12">460.0</td><td title="8 12">0.00934256758129049</td><td style="background-color:Aqua" title="9 12">934.0</td><td title="10 12">0.00762361852522977</td></tr>
# <tr><td style="background-color:LightGreen" title="0 13">Zoroastrian</td><td style="background-color:Aqua" title="1 13">7.0</td><td title="2 13">0.000174146681261817</td><td style="background-color:Aqua" title="3 13">1.0</td><td title="4 13">6.46328852119959e-05</td><td style="background-color:Aqua" title="5 13">0.0</td><td title="6 13">0.0</td><td style="background-color:Aqua" title="7 13">1.0</td><td title="8 13">2.03099295245445e-05</td><td style="background-color:Aqua" title="9 13">9.0</td><td title="10 13">7.34609922131348e-05</td></tr>
# <tr><td style="background-color:LightGreen" title="0 14">Other</td><td style="background-color:Aqua" title="1 14">1194.0</td><td title="2 14">0.0297044482038014</td><td style="background-color:Aqua" title="3 14">425.0</td><td title="4 14">0.0274689762150982</td><td style="background-color:Aqua" title="5 14">543.0</td><td title="6 14">0.0308365040604236</td><td style="background-color:Aqua" title="7 14">1420.0</td><td title="8 14">0.0288400999248533</td><td style="background-color:Aqua" titl

# %%
new_table = c1.topandas()

# %%
import numpy as np
new_table['OBS'].replace('', np.nan, inplace=True)
new_table.dropna(subset=['OBS'], inplace=True)
new_table.rename(columns={'OBS': 'Value'}, inplace=True)
new_table['Value'] = new_table['Value'].astype(int)
new_table['Value'] = new_table['Value'].map(lambda x:''
                                  if (x == '-')
                                  else int(x))

# %%
new_table['Treatment group'] = new_table['Treatment group'].map(
    lambda x: {
        'Total' : 'All' 
        }.get(x, x))

# %%
def user_perc(x):
    
    if x == None :
        return 'All inclusice Inconsistent/missing'
    else:
        return x
    
new_table['Treatment group'] = new_table.apply(lambda row: user_perc(row['Treatment group']), axis = 1)

# %%
new_table['Clients in treatment'] = new_table['Clients in treatment'].map(
    lambda x: {
        'Total' : 'All Clients',
        }.get(x, x))

# %%
new_table = new_table[['Period','Basis of treatment','Treatment group','Clients in treatment','Measure Type','Value','Unit']]

# %%
new_table
# Out:
#                      Period Basis of treatment       Treatment group  \
# 0   2018-03-31T00:00:00/P1Y           religion                Baha'i
# 1   2018-03-31T00:00:00/P1Y           religion                Baha'i
# 2   2018-03-31T00:00:00/P1Y           religion                Baha'i
# 3   2018-03-31T00:00:00/P1Y           religion                Baha'i
# 4   2018-03-31T00:00:00/P1Y           religion                Baha'i
# 5   2018-03-31T00:00:00/P1Y           religion              Buddhist
# 6   2018-03-31T00:00:00/P1Y           religion              Buddhist
# 7   2018-03-31T00:00:00/P1Y           religion              Buddhist
# 8   2018-03-31T00:00:00/P1Y           religion              Buddhist
# 9   2018-03-31T00:00:00/P1Y           religion              Buddhist
# 10  2018-03-31T00:00:00/P1Y           religion             Christian
# 11  2018-03-31T00:00:00/P1Y           religion             Christian
# 12  2018-03-31T00:00:00/P1Y           religion             Christian
# 13  2018-03-31T00:00:00/P1Y           religion             Christian
# 14  2018-03-31T00:00:00/P1Y           religion             Christian
# 3             Alcohol only        Count       5  clients in new treatment
# 4              All Clients        Count      16  clients in new treatment
# 5                   Opiate        Count     243  clients in new treatment
# 6          Non-opiate only        Count      50  clients in new treatment
# 7   Non-opiate and Alcohol        Count      78  clients in new treatment
# 8             Alcohol only        Count     169  clients in new treatment
# 9              All Clients        Count     540  clients in new treatment
# 10                  Opiate        Count    9522  clients in new treatment
# 11         Non-opiate only        Count    3126  clients in new treatment
# 12  Non-opiate and Alcohol        Count    3958  clients in new treatment
# 13            Alcohol only        Count   14943  clients in new treatment
# 14             All Clients        Count   31549  clients in new treatment
# 15                  Opiate        Count     138  clients in new treatment
# 16         Non-opiate only        Count      40  clients in new treatment
# 17  Non-opiate and Alcohol        Count      59  clients in new treatment
# 18            Alcohol only        Count     329  clients in new treatment
# 19             All Clients        Count     566  clients in new treatment
# 20                  Opiate        Count       5  clients in new treatment
# 21         Non-opiate only        Count       1  clients in new treatment
# 22  Non-opiate and Alcohol        Count       2  clients in new treatment
# 23            Alcohol only        Count       6  clients in new treatment
# 24             All Clients        Count      14  clients in new treatment
# 25                  Opiate        Count      49  clients in new treatment
# 26         Non-opiate only        Count      31  clients in new treatment
# 27  Non-opiate and Alcohol        Count      23  clients in new treatment
# 28            Alcohol only        Count      45  clients in new treatment
# 29             All Clients        Count     148  clients in new treatment
# ..                     ...          ...     ...                       ...
# 55                  Opiate        Count   21610  clients in new treatment
# 56         Non-opiate only        Count    9142  clients in new treatment
# 57  Non-opiate and Alcohol        Count   10198  clients in new treatment
# 58            Alcohol only        Count   24514  clients in new treatment
# 59             All Clients        Count   65464  clients in new treatment
# 60                  Opiate        Count    1736  clients in new treatment
# 61         Non-opiate only        Count     669  clients in new treatment
# 62  Non-opiate and Alcohol        Count     836  clients in new treatment
# 63            Alcohol only        Count    2322  clients in new treatment
# 64             All Clients        Count    5563  clients in new treatment
# 65                  Opiate        Count    3941  clients in new treatment
# 66         Non-opiate only        Count    1326  clients in new treatment
# 67  Non-opiate and Alcohol        Count    1420  clients in new treatment
# 68            Alcohol only        Count    4430  clients in new treatment
# 69             All Clients        Count   11117  clients in new treatment
# 70                  Opiate        Count   40196  clients in new treatment
# 71         Non-opiate only        Count   15472  clients in new treatment
# 72  Non-opiate and Alcohol        Count   17609  clients in new treatment
# 73            Alcohol only        Count   49237  clients in new treatment
# 74             All Clients        Count  122514  clients in new treatment
# 75                  Opiate        Count     982  clients in new treatment
# 76         Non-opiate only        Count    1244  clients in new treatment
# 77  Non-opiate and Alcohol        Count    1148  clients in new treatment
# 78            Alcohol only        Count    1419  clients in new treatment
# 79             All Clients        Count    4793  clients in new treatment
# 80                  Opiate        Count   41178  clients in new treatment
# 81         Non-opiate only        Count   16716  clients in new treatment
# 82  Non-opiate and Alcohol        Count   18757  clients in new treatment
# 83            Alcohol only        Count   50656  clients in new treatment
# 84             All Clients        Count  127307  clients in new treatment
#
# [85 rows x 7 columns]
