# %% [markdown]
# Table 4.6.1: Religion, new presentations to treatment

# %%
from gssutils import *

if is_interactive():
    scraper = Scraper('https://www.gov.uk/government/collections/alcohol-and-drug-misuse-and-treatment-statistics')
    scraper.select_dataset(title=lambda x: x.startswith('Substance misuse treatment for adults'), latest=True)
    tabs = {tab.name: tab for tab in scraper.distribution(title=lambda x: x.startswith('Data tables')).as_databaker()}

# %%
tab = tabs['Table 4.6.1']

# %% [markdown]
# https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/752515/AdultSubstanceMisuseNDTMSDataTables2017-18.xlsx

# %%
cell = tab.filter('Religion')
cell.assert_one()
obs = tab.filter('Inconsistent/missing').shift(0,1).expand(RIGHT)
observations = tab.filter('n').fill(DOWN).is_not_blank().is_not_whitespace() - obs
Religion = cell.expand(DOWN).is_not_blank().is_not_whitespace()
Clients = cell.expand(RIGHT).is_not_blank().is_not_whitespace()
Dimensions = [
            HDim(Religion,'Treatment group',DIRECTLY,LEFT),
            HDim(Clients,'Clients in treatment',CLOSEST,LEFT),
            HDimConst('Measure Type','count-of-new-presentations-to-treatment'),
            HDimConst('Unit','new-presentations-to-treatment'),
            HDimConst('Period', 'gregorian-interval/2017-04-01T00:00:00/P1Y')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
if is_interactive():
    savepreviewhtml(c1)
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc0" style="background-color:Aqua">OBS</td><td class="xc1" style="background-color:LightGreen">Treatment group</td><td class="xc2" style="background-color:MistyRose">Clients in treatment</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Table 4.6.1</caption>
# <tr><td title="0 0">Table 4.6.1: Religion, new presentations to treatment</td><td title="1 0"></td><td title="2 0"></td><td title="3 0"></td><td title="4 0"></td><td title="5 0"></td><td title="6 0"></td><td title="7 0"></td><td title="8 0"></td><td title="9 0"></td><td title="10 0"></td></tr>
# <tr><td title="0 1">Link back to the index</td><td title="1 1"></td><td title="2 1"></td><td title="3 1"></td><td title="4 1"></td><td title="5 1"></td><td title="6 1"></td><td title="7 1"></td><td title="8 1"></td><td title="9 1"></td><td title="10 1"></td></tr>
# <tr><td style="background-color:MistyRose" title="0 2">Religion</td><td style="background-color:MistyRose" title="1 2">Opiate</td><td title="2 2"></td><td style="background-color:MistyRose" title="3 2">Non-opiate only</td><td title="4 2"></td><td style="background-color:MistyRose" title="5 2">Non-opiate and Alcohol</td><td title="6 2"></td><td style="background-color:MistyRose" title="7 2">Alcohol only</td><td title="8 2"></td><td style="background-color:MistyRose" title="9 2">Total</td><td title="10 2"></td></tr>
# <tr><td title="0 3"></td><td title="1 3">n</td><td title="2 3">%</td><td title="3 3">n</td><td title="4 3">%</td><td title="5 3">n</td><td title="6 3">%</td><td title="7 3">n</td><td title="8 3">%</td><td title="9 3">n</td><td title="10 3">%</td></tr>
# <tr><td style="background-color:LightGreen" title="0 4">Baha'i</td><td style="background-color:Aqua" title="1 4">8.0</td><td title="2 4">0.000199024778584934</td><td style="background-color:Aqua" title="3 4">2.0</td><td title="4 4">0.000129265770423992</td><td style="background-color:Aqua" title="5 4">1.0</td><td title="6 4">5.67891419160657e-05</td><td style="background-color:Aqua" title="7 4">5.0</td><td title="8 4">0.000101549647622723</td><td style="background-color:Aqua" title="9 4">16.0</td><td title="10 4">0.000130597319490017</td></tr>
# <tr><td style="background-color:LightGreen" title="0 5">Buddhist</td><td style="background-color:Aqua" title="1 5">243.0</td><td title="2 5">0.00604537764951736</td><td style="background-color:Aqua" title="3 5">50.0</td><td title="4 5">0.00323164426059979</td><td style="background-color:Aqua" title="5 5">78.0</td><td title="6 5">0.00442955306945312</td><td style="background-color:Aqua" title="7 5">169.0</td><td title="8 5">0.00343237808964803</td><td style="background-color:Aqua" title="9 5">540.0</td><td title="10 5">0.00440765953278809</td></tr>
# <tr><td style="background-color:LightGreen" title="0 6">Christian</td><td style="background-color:Aqua" title="1 6">9522.0</td><td title="2 6">0.236889242710717</td><td style="background-color:Aqua" title="3 6">3126.0</td><td title="4 6">0.202042399172699</td><td style="background-color:Aqua" title="5 6">3958.0</td><td title="6 6">0.224771423703788</td><td style="background-color:Aqua" title="7 6">14943.0</td><td title="8 6">0.303491276885269</td><td style="background-color:Aqua" title="9 6">31549.0</td><td title="10 6">0.25751342703691</td></tr>
# <tr><td style="background-color:LightGreen" title="0 7">Hindu</td><td style="background-color:Aqua" title="1 7">138.0</td><td title="2 7">0.00343317743059011</td><td style="background-color:Aqua" title="3 7">40.0</td><td title="4 7">0.00258531540847983</td><td style="background-color:Aqua" title="5 7">59.0</td><td title="6 7">0.00335055937304787</td><td style="background-color:Aqua" title="7 7">329.0</td><td title="8 7">0.00668196681357516</td><td style="background-color:Aqua" title="9 7">566.0</td><td title="10 7">0.00461988017695937</td></tr>
# <tr><td style="background-color:LightGreen" title="0 8

new_table['Value'] = new_table['Value'].astype(int)
new_table['Value'] = new_table['Value'].map(lambda x:''
                                  if (x == '-')
                                  else int(x))

# %%
new_table['Basis of treatment'] = new_table['Treatment group'].map(
    lambda x: {
        'Religion':'religion',
        "Baha'i":"religion/bahai",
        'Buddhist':'religion/buddhist',
        'Christian':'religion/christian',
        'Hindu':'religion/hindu',
        'Jain':'religion/jain',
        'Jewish':'religion/jewish',
        'Muslim':'religion/muslim',
        'Pagan':'religion/pagan',
        'Sikh':'religion/sikh',
        'Zoroastrian':'religion/zoroastrian',
        'Other':'religion/other',
        'None':'religion/none',
        'Decline':'religion/decline',
        'Unknown':'religion/unknown',
        'Inconsistent/missing':'religion/inconsistent/missing',
        'Total':'religion/total'        
        }.get(x, x))

# %%
import urllib.request as request
import csv
import io
import requests
vrl="https://raw.githubusercontent.com/ONS-OpenData/ref_alcohol/master/codelists/substance-type.csv"
t=requests.get(vrl).content
g=pd.read_csv(io.StringIO(t.decode('utf-8')))
new_table = pd.merge(new_table, g, how = 'left', left_on = 'Clients in treatment', right_on = 'Label')
new_table.columns = ['Substance type' if x=='Notation' else x for x in new_table.columns]
new_table = new_table[['Period','Basis of treatment','Substance type','Measure Type','Value','Unit']]

# %%
new_table
# Out:
#                                         Period             Basis of treatment  \
# 0   gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/bahai
# 1   gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/bahai
# 2   gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/bahai
# 3   gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/bahai
# 4   gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/bahai
# 5   gregorian-interval/2017-04-01T00:00:00/P1Y              religion/buddhist
# 6   gregorian-interval/2017-04-01T00:00:00/P1Y              religion/buddhist
# 7   gregorian-interval/2017-04-01T00:00:00/P1Y              religion/buddhist
# 8   gregorian-interval/2017-04-01T00:00:00/P1Y              religion/buddhist
# 9   gregorian-interval/2017-04-01T00:00:00/P1Y              religion/buddhist
# 10  gregorian-interval/2017-04-01T00:00:00/P1Y             religion/christian
# 11  gregorian-interval/2017-04-01T00:00:00/P1Y             religion/christian
# 12  gregorian-interval/2017-04-01T00:00:00/P1Y             religion/christian
# 13  gregorian-interval/2017-04-01T00:00:00/P1Y             religion/christian
# 14  gregorian-interval/2017-04-01T00:00:00/P1Y             religion/christian
# 15  gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/hindu
# 16  gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/hindu
# 17  gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/hindu
# 18  gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/hindu
# 19  gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/hindu
# 20  gregorian-interval/2017-04-01T00:00:00/P1Y                  religion/jain
# 21  gregorian-interval/2017-04-01T00:00:00/P1Y                  religion/jain
# 22  gregorian-interval/2017-04-01T00:00:00/P1Y                  religion/jain
# 23  gregorian-interval/2017-04-01T00:00:00/P1Y                  religion/jain
# 24  gregorian-interval/2017-04-01T00:00:00/P1Y                  religion/jain
# 25  gregorian-interval/2017-04-01T00:00:00/P1Y                religion/jewish
# 26  gregorian-interval/2017-04-01T00:00:00/P1Y                religion/jewish
# 27  gregorian-interval/2017-04-01T00:00:00/P1Y                religion/jewish
# 28  gregorian-interval/2017-04-01T00:00:00/P1Y                religion/jewish
# 29  gregorian-interval/2017-04-01T00:00:00/P1Y                religion/jewish
# ..                                         ...                            ...
# 50  gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/other
# 51  gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/other
# 52  gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/other
# 53  gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/other
# 54  gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/other
# 55  gregorian-interval/2017-04-01T00:00:00/P1Y                  religion/none
# 56  gregorian-interval/2017-04-01T00:00:00/P1Y                  religion/none
# 57  gregorian-interval/2017-04-01T00:00:00/P1Y                  religion/none
# 58  gregorian-interval/2017-04-01T00:00:00/P1Y                  religion/none
# 59  gregorian-interval/2017-04-01T00:00:00/P1Y                  religion/none
# 60  gregorian-interval/2017-04-01T00:00:00/P1Y               religion/decline
# 61  gregorian-interval/2017-04-01T00:00:00/P1Y               religion/decline
# 62  gregorian-interval/2017-04-01T00:00:00/P1Y               religion/decline
# 63  gregorian-interval/2017-04-01T00:00:00/P1Y               religion/decline
# 64  gregorian-interval/2017-04-01T00:00:00/P1Y               religion/decline
# 65  gregorian-interval/2017-04-01T00:00:00/P1Y               religion/unknown
# 66  gregorian-interval/2017-04-01T00:00:00/P1Y               religion/unknown
# 67  gregorian-interval/2017-04-01T00:00:00/P1Y               religion/unknown
# 68  gregorian-interval/2017-04-01T00:00:00/P1Y               religion/unknown
# 69  gregorian-interval/2017-04-01T00:00:00/P1Y               religion/unknown
# 70  gregorian-interval/2017-04-01T00:00:00/P1Y  religion/inconsistent/missing
# 71  gregorian-interval/2017-04-01T00:00:00/P1Y  religion/inconsistent/missing
# 72  gregorian-interval/2017-04-01T00:00:00/P1Y  religion/inconsistent/missing
# 73  gregorian-interval/2017-04-01T00:00:00/P1Y  religion/inconsistent/missing
# 74  gregorian-interval/2017-04-01T00:00:00/P1Y  religion/inconsistent/missing
# 75  gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/total
# 76  gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/total
# 77  gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/total
# 78  gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/total
# 79  gregorian-interval/2017-04-01T00:00:00/P1Y                 religion/total
#
#             Substance type Measure Type   Value                  Unit
# 0                   opiate        Count       8  clients-in-treatment
# 1          non-opiate-only        Count       2  clients-in-treatment
# 2   non-opiate-and-alcohol        Count       1  clients-in-treatment
# 3             alcohol-only        Count       5  clients-in-treatment
# 4                    total        Count      16  clients-in-treatment
# 5                   opiate        Count     243  clients-in-treatment
# 6          non-opiate-only        Count      50  clients-in-treatment
# 7   non-opiate-and-alcohol        Count      78  clients-in-treatment
# 8             alcohol-only        Count     169  clients-in-treatment
# 9                    total        Count     540  clients-in-treatment
# 10                  opiate        Count    9522  clients-in-treatment
# 11         non-opiate-only        Count    3126  clients-in-treatment
# 12  non-opiate-and-alcohol        Count    3958  clients-in-treatment
# 13            alcohol-only        Count   14943  clients-in-treatment
# 14                   total        Count   31549  clients-in-treatment
# 15                  opiate        Count     138  clients-in-treatment
# 16         non-opiate-only        Count      40  clients-in-treatment
# 17  non-opiate-and-alcohol        Count      59  clients-in-treatment
# 18            alcohol-only        Count     329  clients-in-treatment
# 19                   total        Count     566  clients-in-treatment
# 20                  opiate        Count       5  clients-in-treatment
# 21         non-opiate-only        Count       1  clients-in-treatment
# 22  non-opiate-and-alcohol        Count       2  clients-in-treatment
# 23            alcohol-only        Count       6  clients-in-treatment
# 24                   total        Count      14  clients-in-treatment
# 25                  opiate        Count      49  clients-in-treatment
# 26         non-opiate-only        Count      31  clients-in-treatment
# 27  non-opiate-and-alcohol        Count      23  clients-in-treatment
# 28            alcohol-only        Count      45  clients-in-treatment
# 29                   total        Count     148  clients-in-treatment
# ..                     ...          ...     ...                   ...
# 50                  opiate        Count    1194  clients-in-treatment
# 51         non-opiate-only        Count     425  clients-in-treatment
# 52  non-opiate-and-alcohol        Count     543  clients-in-treatment
# 53            alcohol-only        Count    1420  clients-in-treatment
# 54                   total        Count    3582  clients-in-treatment
# 55                  opiate        Count   21610  clients-in-treatment
# 56         non-opiate-only        Count    9142  clients-in-treatment
# 57  non-opiate-and-alcohol        Count   10198  clients-in-treatment
# 58            alcohol-only        Count   24514  clients-in-treatment
# 59                   total        Count   65464  clients-in-treatment
# 60                  opiate        Count    1736  clients-in-treatment
# 61         non-opiate-only        Count     669  clients-in-treatment
# 62  non-opiate-and-alcohol        Count     836  clients-in-treatment
# 63            alcohol-only        Count    2322  clients-in-treatment
# 64                   total        Count    5563  clients-in-treatment
# 65                  opiate        Count    3941  clients-in-treatment
# 66         non-opiate-only        Count    1326  clients-in-treatment
# 67  non-opiate-and-alcohol        Count    1420  clients-in-treatment
# 68            alcohol-only        Count    4430  clients-in-treatment
# 69                   total        Count   11117  clients-in-treatment
# 70                  opiate        Count     982  clients-in-treatment
# 71         non-opiate-only        Count    1244  clients-in-treatment
# 72  non-opiate-and-alcohol        Count    1148  clients-in-treatment
# 73            alcohol-only        Count    1419  clients-in-treatment
# 74                   total        Count    4793  clients-in-treatment
# 75                  opiate        Count   41178  clients-in-treatment
# 76         non-opiate-only        Count   16716  clients-in-treatment
# 77  non-opiate-and-alcohol        Count   18757  clients-in-treatment
# 78            alcohol-only        Count   50656  clients-in-treatment
# 79                   total        Count  127307  clients-in-treatment
#
# [80 rows x 6 columns]
