tab.excel_ref('A5').expand(DOWN).is_not_blank()
Substance
# Out:
# {<A13 'Predominantly stimulant'>, <A8 'Ketamine'>, <A24 '** This is a count of individuals as clients may cited multiple NPS substances in the same treatment journey.'>, <A25 'Percentages may equal 0% or not sum to 100% due to rounding'>, <A15 'Predominantly sedative/opioid'>, <A19 'Total number of individuals'>, <A16 'Predominantly hallucinogenic'>, <A12 'Predominantly cannabinoid'>, <A23 '* This total is for the substances listed in the top part of the table (excluding NPS) plus the individual citations of the NPS substances in the bottom half of the table as clients may have multiple citations for different NPS substances. '>, <A14 'Other'>, <A10 'Methamphetamine'>, <A17 'Predominantly dissociative'>, <A20 'Total number in treatment'>, <A5 'Mephedrone'>, <A18 'Total number of citations'>, <A7 'Ecstasy'>, <A9 'GHB/GBL'>, <A11 'Further breakdown of new psychoactive substances:'>, <A6 'New psychoactive substances'>}

# %%
Clients = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
Clients
# Out:
# {<D3 'Non-opiate only'>, <H3 'Total'>, <F3 'Non-opiate and Alcohol'>, <B3 'Opiate'>}

# %%
MeasureType = tab.excel_ref('B4').expand(RIGHT).is_not_blank()
MeasureType
# Out:
# {<H4 'n'>, <C4 '%'>, <D4 'n'>, <E4 '%'>, <G4 '%'>, <I4 '%'>, <F4 'n'>, <B4 'n'>}

# %%
Dimensions = [
            HDim(Substance,'Substance',DIRECTLY,LEFT),
            HDim(Clients,'Clients',CLOSEST,LEFT),
            HDim(MeasureType,'Measure Type',DIRECTLY,ABOVE),
            HDimConst('Unit','People')            
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
# if is_interactive():
#     savepreviewhtml(c1)

# %%
new_table = c1.topandas()
new_table
# Out:
#                OBS                    Substance                 Clients  \
# 0       315.000000                   Mephedrone                  Opiate
# 1         0.002231                   Mephedrone                  Opiate
# 2       255.000000                   Mephedrone         Non-opiate only
# 3         0.010746                   Mephedrone         Non-opiate only
# 4       119.000000                   Mephedrone  Non-opiate and Alcohol
# 5         0.004299                   Mephedrone  Non-opiate and Alcohol
# 6       689.000000                   Mephedrone                   Total
# 7         0.002567                   Mephedrone                   Total
# 8      1103.000000  New psychoactive substances                  Opiate
# 9         0.007812  New psychoactive substances                  Opiate
# 10      630.000000  New psychoactive substances         Non-opiate only
# 11        0.026549  New psychoactive substances         Non-opiate only
# 12      341.000000  New psychoactive substances  Non-opiate and Alcohol
# 13        0.012318  New psychoactive substances  Non-opiate and Alcohol
# 14     2074.000000  New psychoactive substances                   Total
# 15        0.007728  New psychoactive substances                   Total
# 16      318.000000                      Ecstasy                  Opiate
# 17        0.002252                      Ecstasy                  Opiate
# 18      734.000000                      Ecstasy         Non-opiate only
# 19        0.030931                      Ecstasy         Non-opiate only
# 20      623.000000                      Ecstasy  Non-opiate and Alcohol
# 21        0.022504                      Ecstasy  Non-opiate and Alcohol
# 22     1675.000000                      Ecstasy                   Total
# 23        0.006241                      Ecstasy                   Total
# 24      196.000000                     Ketamine                  Opiate
# 25        0.001388                     Ketamine                  Opiate
# 26      600.000000                     Ketamine         Non-opiate only
# 27        0.025284                     Ketamine         Non-opiate only
# 28      340.000000                     Ketamine  Non-opiate and Alcohol
# 29        0.012281                     Ketamine  Non-opiate and Alcohol
# ..             ...                          ...                     ...
# 90       11.000000   Predominantly dissociative         Non-opiate only
# 91        0.000464   Predominantly dissociative         Non-opiate only
# 92       11.000000   Predominantly dissociative  Non-opiate and Alcohol
# 93        0.000397   Predominantly dissociative  Non-opiate and Alcohol
# 94       33.000000   Predominantly dissociative                   Total
# 95        0.000123   Predominantly dissociative                   Total
# 96     2066.000000    Total number of citations                  Opiate
# 97        0.014633    Total number of citations                  Opiate
# 98     2895.000000    Total number of citations         Non-opiate only
# 99        0.121997    Total number of citations         Non-opiate only
# 100    1604.000000    Total number of citations  Non-opiate and Alcohol
# 101       0.057940    Total number of citations  Non-opiate and Alcohol
# 102    6565.000000    Total number of citations                   Total
# 103       0.024461    Total number of citations                   Total
# 104    2025.000000  Total number of individuals                  Opiate
# 105       0.014342  Total number of individuals                  Opiate
# 106    2423.000000  Total number of individuals         Non-opiate only
# 107       0.102107  Total number of individuals         Non-opiate only
# 108    1516.000000  Total number of individuals  Non-opiate and Alcohol
# 109       0.054761  Total number of individuals  Non-opiate and Alcohol
# 110    5964.000000  Total number of individuals                   Total
# 111       0.022221  Total number of individuals                   Total
# 112  141189.000000    Total number in treatment                  Opiate
# 113       1.000000    Total number in treatment                  Opiate
# 114   23730.000000    Total number in treatment         Non-opiate only
# 115       1.000000    Total number in treatment         Non-opiate only
# 116   27684.000000    Total number in treatment  Non-opiate and Alcohol
# 117       1.000000    Total number in treatment  Non-opiate and Alcohol
# 118  268390.000000    Total number in treatment                   Total
# 119       1.000000    Total number in treatment                   Total
#
#     Measure Type    Unit
# 0              n  People
# 1              %  People
# 2              n  People
# 3              %  People
# 4              n  People
# 5              %  People
# 6              n  People
# 7              %  People
# 8              n  People
# 9              %  People
# 10             n  People
# 11             %  People
# 12             n  People
# 13             %  People
# 14             n  People
# 15             %  People
# 16             n  People
# 17             %  People
# 18             n  People
# 19             %  People
# 20             n  People
# 21             %  People
# 22             n  People
# 23             %  People
# 24             n  People
# 25             %  People
# 26             n  People
# 27             %  People
# 28             n  People
# 29             %  People
# ..           ...     ...
# 90             n  People
# 91             %  People
# 92             n  People
# 93             %  People
# 94             n  People
# 95             %  People
# 96             n  People
# 97             %  People
# 98             n  People
# 99             %  People
# 100            n  People
# 101            %  People
# 102            n  People
# 103            %  People
# 104            n  People
# 105            %  People
# 106            n  People
# 107            %  People
# 108            n  People
# 109            %  People
# 110            n  People
# 111            %  People
# 112            n  People
# 113            %  People
# 114            n  People
# 115            %  People
# 116            n  People
# 117            %  People
# 118            n  People
# 119            %  People
#
# [120 rows x 5 columns]

# %%
new_table = new_table[new_table['OBS'] != 0 ]

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table['Measure Type'] = new_table['Measure Type'].map(
    lambda x: {
        'n' : 'Count', 
        '%' : 'Percentage',
        }.get(x, x))

# %%
new_table.head()
# Out:
#         Value   Substance                 Clients Measure Type    Unit
# 0  315.000000  Mephedrone                  Opiate        Count  People
# 1    0.002231  Mephedrone                  Opiate   Percentage  People
# 2  255.000000  Mephedrone         Non-opiate only        Count  People
# 3    0.010746  Mephedrone         Non-opiate only   Percentage  People
# 4  119.000000  Mephedrone  Non-opiate and Alcohol        Count  People

# %%
new_table.dtypes
# Out:
# Value           float64
# Substance        object
# Clients          object
# Measure Type     object
# Unit             object
# dtype: object

# %%
new_table['Value'] = new_table['Value'].astype(str)

# %%
# def user_perc(x,y):
    
#     if x == 'Count':
#         return str(y)
#     else:
#         return y
    
# new_table['Value'] = new_table.apply(lambda row: user_perc(row['Measure Type'], row['Value']), axis = 1)

# %%
new_table.head(3)
# Out:
#                  Value   Substance          Clients Measure Type    Unit
# 0                315.0  Mephedrone           Opiate        Count  People
# 1  0.00223105199413552  Mephedrone           Opiate   Percentage  People
# 2                255.0  Mephedrone  Non-opiate only        Count  People

# %%
new_table['Clients'] = new_table['Clients'].map(
    lambda x: {
        'Total' : 'All Clients' 
        }.get(x, x))

# %%
new_table.columns = ['Clients in treatment' if x=='Clients' else x for x in new_table.columns]
new_table['Period'] = '2017-18'
new_table['Basis of treatment'] = 'All'
new_table = new_table[['Period','Basis of treatment','Substance','Clients in treatment','Measure Type','Value','Unit']]
